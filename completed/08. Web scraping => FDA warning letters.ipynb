# %% [markdown]
# # Web scraping: FDA warning letters
#
# In this notebook, we're going to write some code to scrape [tables of data on FDA warning letters issued in 2018](https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm).
#
# We'll also talk about how we might extend this idea to get warning letters from other years, as well.
#
# First, let's think through the process and decide what tools we'll need. Our goal is to fetch a web page (`requests`), parse the HTML (`bs4`) and write to a local file (`csv`). Let's import what we need:

# %%
import csv

import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### Now we noodle
#
# The data table of warning letters is spread across multiple pages. What happens when you click "Next" or a page number? The URL changes from this:
#
# [`https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm`](https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm)
#
# to this:
#
# [`https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm?Page=2`](https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm?Page=2)
#
# What's happening is, a [URL _parameter_](https://en.wikipedia.org/wiki/Query_string) is being appended. This gives the database instructions about how to formulate a response to your browser's request: Show me the letters on page 2.
#
# What happens when you specify `Page=1`?
#
# [`https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm?Page=1`](https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm?Page=1)
#
# We're back to the first page. This is good news, because it means we can iterate over the number of pages in the results, starting with Page 1, and grab what we need.
#
# What happens when we specify a page number that doesn't exist?
#
# [`https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm?Page=100`](https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm?Page=100)
#
# We get a page that includes the text "No Current Postings Available" -- something we'll remember as we write our scraper.

# %% [markdown]
# ### Save files locally
#
# It's good practice to save the HTML files you want to scrape. So we're going to do that here -- save a copy of each page of results on the FDA site.
#
# First, let's establish a few variables:
# - The base URL we'll start from
# - The naming pattern of the local files we're going to save -- we're going to use [string formatting](../reference/String%20formatting.ipynb)

# %%
BASE_URL = 'https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/2018/default.htm'
LOCAL_FILE_PATT = 'fda-warning-letters-{pagenum}.html'

# %% [markdown]
# There are a bunch of different strategies we could use to grab these pages. Here's what we'll try today:
# 1. Look at the page numbers you could navigate to and grab the largest one
# 2. Loop over a range of numbers from 1 to the largest number in the pagination list (which we just grabbed)
# 3. Retrieve each page of results
# 4. If that page exists -- in other words, if the web page doesn't say "No Current Postings Available" -- save it; if not, break out of the loop because we're done (this is just an extra sanity check)
#
# Why, you ask, don't we just loop over the numbers 1-5? We know that there are only 5 pages. Great question! Generally, you want to avoid hard-coding numbers in situations where numbers could change. As the FDA adds more warning letters, the database will return more than 5 pages of results, and our script would miss those.
#
# First, let's grab the page and isolate the element with the maximum page number. Then we'll know how many pages we need to loop over.
#
# In a new tab, crack open the page to view the source code. Then use `requests` to get the page and `bs4` to parse the HTML.

# %%
r = requests.get(BASE_URL)
soup = BeautifulSoup(r.text, 'html.parser')

# %% [markdown]
# Find the list of page numbers at the bottom -- I Ctrl-F'd for "Previous" to find it. Turns out it's an unordered list (`ul`) with the class `pagination-clean`.

# %%
pagination = soup.find('ul', {'class': 'pagination-clean'})
print(pagination)
# Out:
# <ul class="pagination-clean">
# <li class="previous-off">Previous</li>
# <li class="active">1</li>
# <li><a href="/ICECI/EnforcementActions/WarningLetters/2018/default.htm?Page=2">2</a></li>
# <li><a href="/ICECI/EnforcementActions/WarningLetters/2018/default.htm?Page=3">3</a></li>
# <li><a href="/ICECI/EnforcementActions/WarningLetters/2018/default.htm?Page=4">4</a></li>
# <li><a href="/ICECI/EnforcementActions/WarningLetters/2018/default.htm?Page=5">5</a></li>
# <li class="next"><a href="?Page=2">Next</a></li>
# </ul>

# %% [markdown]
# We want to isolate the numbers and grab the biggest. Couple ways to skin this cat, but today, let's pull the text of each item in that `ul` into a Python list -- only if it's a number, though! -- and find the biggest one.
#
# Three new-to-us functions are going to help us out here:
# - [`isnumeric()`](https://www.tutorialspoint.com/python/string_isnumeric.htm), a string method that checks whether the contents of a string are numeric ('4' => True, 'Hello!' => False)
# - [`int()`](https://docs.python.org/3/library/functions.html#int), a function to coerce a value to an integer
# - [`max()`](https://docs.python.org/3/library/functions.html#max), a function to get the biggest number out of a list
#
# We're going to use a _for loop_ to iterate over the items (`li`) inside the list (`ul`).
#
# 👉 For a refresher on for loops, [see this notebook](../reference/Python%20data%20types%20and%20basic%20syntax.ipynb#for-loops)

# %%
# an empty list to hold the page numbers
page_numbers = []

# loop over the items in the pagination list
for li in pagination.find_all('li'):
    
    # get the text inside the tag and strip whitespace
    txt = li.string.strip()
    
    # if it's numeric
    if txt.isnumeric():
        
        # coerce to an integer (`int()`) and `append()` to our list
        page_numbers.append(int(txt))

# create a new variable with the biggest number in that list
max_page_num = max(page_numbers)

'''
~ BONUS CONTENT ~

A one-liner to do this would use something called a "list comprehension"
https://docs.python.org/3/tutorial/datastructures.html#list-comprehensions

max_page_num = max([int(x.string.strip()) for x in pagination.find_all('li')
                    if x.string.strip().isnumeric()])

'''

print(max_page_num)
# Out:
# 5

# %% [markdown]
# So now we have the number of pages we need to loop over. We'll use the [`range()`](https://docs.python.org/3/library/functions.html#func-range) function to loop over the range of numbers we're interested in -- keeping in mind that the second number you give to the range function is the _first_ number that you _don't_ want to include. In other words, we need to add 1 to our `max_page_num` variable to get what we need.
#
# To demonstrate:

# %%
for i in range(1, max_page_num):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1, max_page_num+1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Five requests to a server isn't really a big deal, but just to be courteous we'll pause for a second between requests. For that, we'll use `sleep()`, a method in Python's built-in `time` module. Let's import `time` now.

# %%
import time

# %% [markdown]
# Now, to save our pages. We'll loop over a list of page numbers (1 to max page number) and request the FDA page of results associated with that page number and save to file.
#
# Along the way, if we see the 'no current postings available' text, something went wrong and we want to break out of the loop. To do this, we'll use a [`break`](https://docs.python.org/3/reference/simple_stmts.html#break).
#
# 👉 For more information on _if_ statements, [check out this notebook](../reference/Python%20data%20types%20and%20basic%20syntax.ipynb#if-statements).

# %%
# loop over the numbers 1 to max_page_num+1
for i in range(1, max_page_num+1):
    
    # get the page, specifying the 'Page' parameter
    r = requests.get(BASE_URL, params={'Page': i})
    
    # bail if the "nothing here" text shows up
    if 'no current postings available' in r.text.lower():
        break

    # otherwise, save the page
    else:
        with open(LOCAL_FILE_PATT.format(pagenum=i), 'w') as o:
            o.write(r.text)

    # print something to let us know it's working
    print('Saving page', i)
    
    # pause 1 second
    time.sleep(1)

# %% [markdown]
# ### Scrape the HTML
#
# Now that we've saved the HTML locally, let's get to work scraping it. Let's open the first one as a test and turn it into soup.

# %%
with open('fda-warning-letters-1.html', 'r') as i:
    html = i.read()
    soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# Next, look for the data we want to scrape. It's in a `<table>` element with the ID `WarningLetter_sortid`. (It also appears to be the only table on the page.)

# %%
table = soup.find('table', {'id': 'WarningLetter_sortid'})
print(table)
# Out:
# <table class="tablesorter" id="WarningLetter_sortid" summary="Layout showing WarningLetter table with 5 columns: Letter Issue Date, Company Name, Issuing Office, Subject, Close Out Date">
# <thead>
# <tr>
# <th data-toggle="true" data-type="numeric" scope="col"> Letter Issue Date </th>
# <th scope="col">  Company Name </th>
# <th data-hide="phone" scope="col">  Issuing Office </th>
# <th data-hide="phone" scope="col">  Subject </th>
# <th data-hide="phone,tablet" data-type="numeric" scope="col">  Close Out Date </th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td
Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/21/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610919.htm">Oeyama-Moto-Medical Group Foundation, LLC</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Good Laboratory Practice (GLP) for Nonclinical Laboratory Studies</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/18/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm607901.htm">Kratom Spot</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Unapproved New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/18/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm608257.htm">GliSODin Skin Nutrients</a></td>
# <td> Center for Food Safety and Applied Nutrition</td>
# <td> New Drug/Labeling/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# Neato. What data are we extracting? The fields on the table are: `Letter Issue`, `Date`, `Company Name`, `Issuing Office`, `Subject`, `Close Out Date`. The company name also has a link to the actual letter, so we'd want to grab that, too. Let's define the field names for our CSV in a list:

# %%
headers = ['company', 'issue_date', 'letter_url', 'issuing_office', 'subject', 'closeout_date']

# %% [markdown]
# We'll start by looping over the rows (`<tr>`) in the table and seeing what we can pull out. Remember: The `find_all()` method returns a list that we can iterate over.

# %%
for row in table.find_all('tr'):
    print(row)
# Out:
# <tr>
# <th data-toggle="true" data-type="numeric" scope="col"> Letter Issue Date </th>
# <th scope="col">  Company Name </th>
# <th data-hide="phone" scope="col">  Issuing Office </th>
# <th data-hide="phone" scope="col">  Subject </th>
# <th data-hide="phone,tablet" data-type="numeric" scope="col">  Close Out Date </th>
# </tr>
# <tr>
# <td>07/19/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm614420.htm">Niche Pharmaceuticals, Inc</a></td>
# <td> Dallas District Office</td>
# <td> Unapproved New Drugs/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>07/10/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm613879.htm">Gipsco Investment Corp</a></td>
# <td> Detroit District Office</td>
# <td> Compounding Pharmacy/Adulterated Drug Products</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>07/09/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm613621.htm">Roorda Dairy</a></td>
# <td> Kansas City District Office</td>
# <td> Food/Edible Tissue/Drug Residue/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>07/06/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm613243.htm">Aegle Nutrition LLC</a></td>
# <td> Dallas District Office</td>
# <td> CGMP/Dietary Supplement/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>07/05/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm613538.htm">Claris Injectables Limited</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> CGMP/Finished Pharmaceuticals/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>07/03/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm613604.htm">AniCell Biotech</a></td>
# <td> Los Angeles District Office</td>
# <td> Unapproved New Animal Drug/Adultered</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>07/03/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm613546.htm">bB BioChem Laboratories Inc.</a></td>
# <td> Los Angeles District Office</td>
# <td> CGMP/Finished Pharmaceuticals/Adulterated/Unapproved New Drug</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/29/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm613578.htm">Holy Land Brand Inc.</a></td>
# <td> Minneapolis District Office</td>
# <td> CGMP/Food/Prepared, Packed or Held Under Insanitary Conditions/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/27/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm612885.htm">Zhuhai United Laboratories Co. Ltd.</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> CGMP/Finished Pharmaceuticals/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/26/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm612483.htm">Foshan Jinxiong Technology Co., Ltd.</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> CGMP/Finished Pharmaceuticals/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/26/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm612377.htm">American Chinese Medicine Association</a></td>
# <td> Detroit District Office</td>
# <td> New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/22/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm612389.htm">Sichuan Friendly Pharmaceutical Co., Ltd.</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> CGMP/Active Pharmaceutical Ingredient (API)/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/20/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm612338.htm">KPC Products Inc</a></td>
# <td> Los Angeles District Office</td>
# <td> CGMP/Dietary Supplement/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/12/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm611369.htm">Henan Lihua Pharmaceutical Co., Ltd.</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> CGMP/Active Pharmaceutical Ingredient (API)/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/12/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610875.htm">Ami Cosmetics Co., Ltd.</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Failure to Comply with Drug Listing Requirements/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/11/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610626.htm">LNZRO Pizza Empire, Inc.</a></td>
# <td> New York District Office</td>
# <td> Seafood HACCP/CGMP for Foods/Adulterated/Insanitary Conditions</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/08/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610611.htm">Kaltec Food Packaging Inc.</a></td>
# <td> New York District Office</td>
# <td> Acidified Foods/Emergency Permit Control/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/08/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610849.htm">BR SAS</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> CGMP/Finished Pharmaceuticals/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/07/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610604.htm">Up Inya Gear</a></td>
# <td> Center for Food Safety and Applied Nutrition</td>
# <td> New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>06/06/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610661.htm">The Health Management Group Inc.</a></td>
# <td> Cincinnati District Office</td>
# <td> CGMP/Dietary Supplement/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/31/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610754.htm">Hells Vapors LLC</a></td>
# <td> Center for Tobacco Products</td>
# <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/31/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610084.htm">Vapestar</a></td>
# <td> Center for Tobacco Products</td>
# <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/31/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609829.htm">Taiwan Biotech Co., LTD.</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> CGMP/Finished Pharmaceuticals/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/31/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610055.htm">Global Vapery</a></td>
# <td> Center for Tobacco Products</td>
# <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/31/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm611763.htm">Jacobs Pills, Inc.</a></td>
# <td> New Jersey District Office</td>
# <td> Compounding Pharmacy/Adulterated Drug Products</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/31/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609643.htm">Fair Fish Co., Inc.</a></td>
# <td> New York District Office</td>
# <td> Seafood HACCP/CGMP for Foods/Adulterated/Insanitary Conditions</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/31/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610758.htm">Northwoods Vape Escape LLC</a></td>
# <td> Center for Tobacco Products</td>
# <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/30/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610073.htm">JSST Enterprises LLC</a></td>
# <td> Center for Tobacco Products</td>
# <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/30/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610744.htm">Savage Juice</a></td>
# <td> Center for Tobacco Products</td>
# <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/30/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610749.htm">Blowing Vapors</a></td>
# <td> Center for Tobacco Products</td>
# <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/30/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610750.htm">Swamp Vapor Lafayette</a></td>
# <td> Center for Tobacco Products</td>
# <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/30/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610740.htm">Hi Five Ohm Vape Co</a></td>
# <td> Center for Tobacco Products</td>
# <td> Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/29/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609821.htm">Eassybuyonline</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/29/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609529.htm">LiquidCaffeine.com</a></td>
# <td> Center for Food Safety and Applied Nutrition</td>
# <td> Dietary Supplement/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/29/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609672.htm">XLPharmacy</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/29/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609749.htm">RxCash.Biz</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/29/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609814.htm">Medstore.biz</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/29/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609822.htm">AnonShop</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/29/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609527.htm">Dual Health Body and Mind</a></td>
# <td> Center for Food Safety and Applied Nutrition</td>
# <td> Dietary Supplement/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/29/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609818.htm">Instabill ECSâRx</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/29/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609739.htm">TramadolHub</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/29/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609762.htm">RemedyMart</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/29/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609780.htm">One Stop Pharma</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Finished Pharmaceuticals/Unapproved New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/24/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm612480.htm">Bimeda, Inc.</a></td>
# <td> Center for Veterinary Medicine</td>
# <td> False &amp; Misleading Claims/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/24/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609165.htm">The Fertility Partnership LLC</a></td>
# <td> Chicago District Office</td>
# <td> Deviations/CFR/Regulations for Human Cells, Tissues &amp; Cellular Products (HCT/Ps)</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/23/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609195.htm">IDT Australia Ltd.</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> CGMP/Active Pharmaceutical Ingredient (API)/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/23/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm609133.htm">Creative Science, Inc.</a></td>
# <td> Detroit District Office</td>
# <td> Human Drug/Marketing/Animal Drug/Unsafe/Adulterated</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/21/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm610919.htm">Oeyama-Moto-Medical Group Foundation, LLC</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Good Laboratory Practice (GLP) for Nonclinical Laboratory Studies</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/18/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm607901.htm">Kratom Spot</a></td>
# <td> Center for Drug Evaluation and Research</td>
# <td> Unapproved New Drug/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>
# <tr>
# <td>05/18/2018 </td>
# <td style="text-decoration: underline;"><a href="/ICECI/EnforcementActions/WarningLetters/ucm608257.htm">GliSODin Skin Nutrients</a></td>
# <td> Center for Food Safety and Applied Nutrition</td>
# <td> New Drug/Labeling/Misbranded</td>
# <td nowrap="">
# <a href="#wldisclaimer">Not Issued *</a>
# </td>
# </tr>

# %% [markdown]
# Perf. Let's use list slicing to skip the header row, though, and start extracting the data.

# %%
# loop over the table rows, skipping the first [0] one
for row in table.find_all('tr')[1:]:
    
    # get a list of table data elements in this row
    cols = row.find_all('td')
    
    # first one [0] has the date
    date = cols[0].string.strip()
    
    # second one [1] has the company
    company = cols[1].string.strip()
    
    # URL also in second one; prepend the base URL
    url = 'https://www.fda.gov' + cols[1].a['href']
    
    # third one [2] has the office
    office = cols[2].string.strip()

    # fourth one [3] has the subject
    subject = cols[3].string.strip()
    
    # fifth one [4] has the closeout date
    # using `text` instead of `string` because the text is actually inside the nested `a`
    closeout_date = cols[4].text.strip()
    
    # print it to see what we've got
    print(company, date, url, office, subject, closeout_date)
    print('-'*60)
# Out:
# Niche Pharmaceuticals, Inc 07/19/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm614420.htm Dallas District Office Unapproved New Drugs/Misbranded Not Issued *
# ------------------------------------------------------------
# Gipsco Investment Corp 07/10/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm613879.htm Detroit District Office Compounding Pharmacy/Adulterated Drug Products Not Issued *
# ------------------------------------------------------------
# Roorda Dairy 07/09/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm613621.htm Kansas City District Office Food/Edible Tissue/Drug Residue/Adulterated Not Issued *
# ------------------------------------------------------------
# Aegle Nutrition LLC 07/06/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm613243.htm Dallas District Office CGMP/Dietary Supplement/Adulterated/Misbranded Not Issued *
# ------------------------------------------------------------
# Claris Injectables Limited 07/05/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm613538.htm Center for Drug Evaluation and Research CGMP/Finished Pharmaceuticals/Adulterated Not Issued *
# ------------------------------------------------------------
# AniCell Biotech 07/03/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm
htm Center for Food Safety and Applied Nutrition New Drug/Labeling/Misbranded Not Issued *
# ------------------------------------------------------------

# %% [markdown]
# Cool! Let's try it with the other files. How might we get a list of the HTML files we downloaded earlier? If you didn't know already, how might you formulate your search terms for Google? (I might start with something like "[python get specific files in directory](https://www.google.com/search?q=python+get+specific+files+in+directory)," which leads me to [a StackOverflow question](https://stackoverflow.com/questions/3964681/find-all-files-in-a-directory-with-extension-txt-in-python) from someone who was trying to find all of the `.txt` files in a directory.)
#
# Appears that [`glob`](https://docs.python.org/3/library/glob.html) is our horse here. Let's import `glob` and target our files:

# %%
import glob

results_pages = glob.glob('fda-warning-letters-*.html')
print(results_pages)
# Out:
# ['fda-warning-letters-2.html', 'fda-warning-letters-3.html', 'fda-warning-letters-4.html', 'fda-warning-letters-5.html', 'fda-warning-letters-1.html']

# %% [markdown]
# Winner winner, chicken dinner. Now we can loop over each one and extract the data we need from each.

# %%
# loop over the results pages
for page in results_pages:
    
    # open the page, read the HTML, turn it into soup
    with open(page, 'r') as i:
        html = i.read()
        soup = BeautifulSoup(html, 'html.parser')

    # find the table
    table = soup.find('table', {'id': 'WarningLetter_sortid'})

    # loop over the table rows, skipping the first [0] one
    for row in table.find_all('tr')[1:]:

        # get a list of table data elements in this row
        cols = row.find_all('td')

        # first one [0] has the date
        date = cols[0].string.strip()

        # second one [1] has the company
        company = cols[1].string.strip()

        # URL also in second one; prepend the base URL
        url = 'https://www.fda.gov' + cols[1].a['href']

        # third one [2] has the office
        office = cols[2].string.strip()

        # fourth one [3] has the subject
        subject = cols[3].string.strip()

        # fifth one [4] has the closeout date
        # using `text` instead of `string` because the text is actually inside the nested `a`
        closeout_date = cols[4].text.strip()

        # print it to see what we've got
        print(company, date, url, office, subject, closeout_date)
        print('-'*60)
# Out:
# Sunergized LLC 05/18/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm608259.htm Center for Food Safety and Applied Nutrition New Drug/Labeling/Misbranded 06/19/2018
# ------------------------------------------------------------
# Revibe, Inc. 05/18/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm607904.htm Center for Drug Evaluation and Research Unapproved New Drug/Misbranded Not Issued *
# ------------------------------------------------------------
# Napa Valley Bioscience 05/18/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm608260.htm Center for Food Safety and Applied Nutrition New Drug/Labeling/Misbranded Not Issued *
# ------------------------------------------------------------
# Performance Nutrition Formulators LLC dba VMI Sports 05/18/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm608716.htm Center for Food Safety and Applied Nutrition CGMP/Manufacturing, Packaging, Labeling, or Holding Operations for Dietary Supplements/Adulterated Not Issued *
# ------------------------------------------------------------
# Kolmar Korea Co. Ltd. 05/18/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609136.htm Center for Drug Evaluation and Research CGMP/Finished Pharmaceuticals/Adulterated Not Issued *
# ------------------------------------------------------------
# CV7 Holdings LLC 05/18/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm608214.htm Center for Food Safety and Applied Nutrition New Drug/Labeling/Misbranded Not Issued *
# ------------------------------------------------------------
# Pharmacy Direct, PDU 05/18/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm608220.htm Center for Food Safety and Applied Nutrition New Drug/Labeling/Misbranded 06/19/2018
# ------------------------------------------------------------
# Front Range Kratom 05/18/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm607903.htm Center for Drug Evaluation and Research Unapproved New Drug/Misbranded Not Issued *
# ------------------------------------------------------------
# Jalco Cosmetics Pty Ltd. 05/18/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm608717.htm Center for Drug Evaluation and Research CGMP/Finished Pharmaceuticals/Adulterated Not Issued *
# ------------------------------------------------------------
# Orangeburg Pecan Company Inc 05/17/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm608709.htm Atlanta District Office CGMP/Food/Prepared, Packed or Held Under Insanitary Conditions/Adulterated Not Issued *
# ------------------------------------------------------------
# Silver Armor, Inc. 05/17/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609437.htm Atlanta District Office Unapproved New Drugs/Misbranded Not Issued *
# ------------------------------------------------------------
# Europharma Concepts Limited 05/16/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm607950.htm Center for Drug Evaluation and Research CGMP/Finished Pharmaceuticals/Adulterated Not Issued *
# ------------------------------------------------------------
# New England Confectionery Company, Inc. 05/16/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm607845.htm Center for Food Safety and Applied Nutrition CGMP/Food/Prepared, Packed or Held Under Insanitary Conditions/Adulterated Not Issued *
# ------------------------------------------------------------
# Cerno Pharmaceutical 05/15/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm607695.htm Dallas District Office CGMP/Finished Pharmaceuticals/Adulterated Not Issued *
# ------------------------------------------------------------
# Jilin Shulan Synthetic Pharmaceutical Co. Ltd. 05/14/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm608713.htm Center for Drug Evaluation and Research CGMP/APIs/Adulterated Not Issued *
# ------------------------------------------------------------
# 13th Floor Elevapors, LLC 05/10/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm605912.htm Center for Tobacco Products Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded Not Issued *
# ------------------------------------------------------------
# Chill E-Liquid 05/10/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm605903.htm Center for Tobacco Products Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded Not Issued *
# ------------------------------------------------------------
# VallHund Vapes Inc. 05/10/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm605909.htm Center for Tobacco Products Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded Not Issued *
# ------------------------------------------------------------
# Virtue Vape, LLC 05/10/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm605925.htm Center for Tobacco Products Family Smoking Prevention and Tobacco Control Act/Adulterated/Misbranded Not Issued *
# ------------------------------------------------------------
# Montana Compounding Pharmacy PC 05/09/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm607912.htm Los Angeles District Office Compounding Pharmacy/Adulterated Drug Products Not Issued *
# ------------------------------------------------------------
# Nox Bellcow Cosmetics Co. Ltd. 05/09/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm607820.htm Center for Drug Evaluation and Research CGMP/Finished Pharmaceuticals/Adulterated Not Issued *
# ------------------------------------------------------------
# Reine Lifescience 05/09/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm607583.htm Center for Drug Evaluation and Research CGMP/Active Pharmaceutical Ingredient (API)/Adulterated Not Issued *
# ------------------------------------------------------------
# Emmett F. Branigan, MD, PS, Inc 05/07/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm607671.htm Los Angeles District Office Deviations/CFR/Regulations for Human Cells, Tissues & Cellular Products (HCT/Ps) 07/05/2018
# ------------------------------------------------------------
# Cosmic Fog Vapors LLC 05/01/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm
05/29/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609529.htm Center for Food Safety and Applied Nutrition Dietary Supplement/Adulterated Not Issued *
# ------------------------------------------------------------
# XLPharmacy 05/29/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609672.htm Center for Drug Evaluation and Research Finished Pharmaceuticals/Unapproved New Drug/Misbranded Not Issued *
# ------------------------------------------------------------
# RxCash.Biz 05/29/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609749.htm Center for Drug Evaluation and Research Finished Pharmaceuticals/Unapproved New Drug/Misbranded Not Issued *
# ------------------------------------------------------------
# Medstore.biz 05/29/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609814.htm Center for Drug Evaluation and Research Finished Pharmaceuticals/Unapproved New Drug/Misbranded Not Issued *
# ------------------------------------------------------------
# AnonShop 05/29/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609822.htm Center for Drug Evaluation and Research Finished Pharmaceuticals/Unapproved New Drug/Misbranded Not Issued *
# ------------------------------------------------------------
# Dual Health Body and Mind 05/29/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609527.htm Center for Food Safety and Applied Nutrition Dietary Supplement/Adulterated Not Issued *
# ------------------------------------------------------------
# Instabill ECSâRx 05/29/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609818.htm Center for Drug Evaluation and Research Finished Pharmaceuticals/Unapproved New Drug/Misbranded Not Issued *
# ------------------------------------------------------------
# TramadolHub 05/29/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609739.htm Center for Drug Evaluation and Research Finished Pharmaceuticals/Unapproved New Drug/Misbranded Not Issued *
# ------------------------------------------------------------
# RemedyMart 05/29/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609762.htm Center for Drug Evaluation and Research Finished Pharmaceuticals/Unapproved New Drug/Misbranded Not Issued *
# ------------------------------------------------------------
# One Stop Pharma 05/29/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609780.htm Center for Drug Evaluation and Research Finished Pharmaceuticals/Unapproved New Drug/Misbranded Not Issued *
# ------------------------------------------------------------
# Bimeda, Inc. 05/24/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm612480.htm Center for Veterinary Medicine False & Misleading Claims/Misbranded Not Issued *
# ------------------------------------------------------------
# The Fertility Partnership LLC 05/24/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609165.htm Chicago District Office Deviations/CFR/Regulations for Human Cells, Tissues & Cellular Products (HCT/Ps) Not Issued *
# ------------------------------------------------------------
# IDT Australia Ltd. 05/23/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609195.htm Center for Drug Evaluation and Research CGMP/Active Pharmaceutical Ingredient (API)/Adulterated Not Issued *
# ------------------------------------------------------------
# Creative Science, Inc. 05/23/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm609133.htm Detroit District Office Human Drug/Marketing/Animal Drug/Unsafe/Adulterated Not Issued *
# ------------------------------------------------------------
# Oeyama-Moto-Medical Group Foundation, LLC 05/21/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm610919.htm Center for Drug Evaluation and Research Good Laboratory Practice (GLP) for Nonclinical Laboratory Studies Not Issued *
# ------------------------------------------------------------
# Kratom Spot 05/18/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm607901.htm Center for Drug Evaluation and Research Unapproved New Drug/Misbranded Not Issued *
# ------------------------------------------------------------
# GliSODin Skin Nutrients 05/18/2018 https://www.fda.gov/ICECI/EnforcementActions/WarningLetters/ucm608257.htm Center for Food Safety and Applied Nutrition New Drug/Labeling/Misbranded Not Issued *
# ------------------------------------------------------------

# %% [markdown]
# Excellent! Instead of just printing the rows, we want to write them out to a CSV. Let's put it all together:

# %%
# open a new csv file to write to
with open('fda-warning-letters-2018.csv', 'w') as o:
    
    # create a writer object, specifying the fieldnames
    writer = csv.DictWriter(o, fieldnames=headers)
    
    # write the header row
    writer.writeheader()
    
    # loop over the HTML pages
    for page in results_pages:
        # open the page, read the HTML, turn it into soup
        with open(page, 'r') as i:
            html = i.read()
            soup = BeautifulSoup(html, 'html.parser')
        
        # find the table
        table = soup.find('table', {'id': 'WarningLetter_sortid'})

        # loop over the table rows, skipping the first [0] one
        for row in table.find_all('tr')[1:]:

            # get a list of table data elements in this row
            cols = row.find_all('td')

            # first one [0] has the date
            date = cols[0].string.strip()

            # second one [1] has the company
            company = cols[1].string.strip()

            # URL also in second one; prepend the base URL
            url = 'https://www.fda.gov' + cols[1].a['href']

            # third one [2] has the office
            office = cols[2].string.strip()

            # fourth one [3] has the subject
            subject = cols[3].string.strip()

            # fifth one [4] has the closeout date
            # using `text` instead of `string` because the text is actually inside the nested `a`
            closeout_date = cols[4].text.strip()

            # write row to csv
            writer.writerow({
                'company': company,
                'issue_date': date,
                'letter_url': url,
                'issuing_office': office,
                'subject': subject,
                'closeout_date': closeout_date   
            })

# %% [markdown]
# So there we have it. At this point, I would go back and refactor the code to break up tasks into discrete [functions](../reference/Functions.ipynb).

# %% [markdown]
# ### Next up: How to get multiple years' worth of data?
#
# A class discussion + extra credit assignment.
