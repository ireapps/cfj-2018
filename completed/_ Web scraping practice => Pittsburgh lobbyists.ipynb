# %% [markdown]
# # Web scraping practice: Pittsburgh lobbyists
#
# We're going to scrape [a database of people registered to lobby the city of Pittsburgh](http://www.openbookpittsburgh.com/SearchLobbyists.aspx).
#
# First, let's import the packages we'll need: `csv`, `requests`, `bs4`, `pandas`.

# %%
import csv

import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### Noodle around
#
# Navigate to the page we're going to scrape. We want everyone -- what happens when you hit "search" without entering any criteria into the form? It works! (This won't always be the case for databases like this.) As of July 28, 2018, the search showed 83 lobbyists.
#
# Notice, too, that the URL has changed from this:
#
# `http://www.openbookpittsburgh.com/SearchLobbyists.aspx`
#
# To this:
#
# `http://www.openbookpittsburgh.com/SearchLobbyists.aspx?&page=0&cat=LobbyistName&sort=ASC&num=10&click=1`
#
# After the `?` are the URL _parameters_, separated by `&`:
# - `page=0`
# - `cat=LobbyistName`
# - `sort=ASC`
# - `num=10`
# - `click=1`
#
# These are the instructions that get passed to the database after we click search: Return results under the category "Lobbyist Name," show 10 lobbyists at a time, sort ascending, starting with page zero (the first page).
#
# (What happens if you _do_ put something in the search field? A new parameter is added to the URL: `lobbyist=`. But we want everything, so we can ignore this.)
#
# What happens if we tweak the URL and instruct the database to show us _100_ results at a time? Try it:
#
# [`http://www.openbookpittsburgh.com/SearchLobbyists.aspx?&page=0&cat=LobbyistName&sort=ASC&num=100&click=1`](`http://www.openbookpittsburgh.com/SearchLobbyists.aspx?&page=0&cat=LobbyistName&sort=ASC&num=100&click=1`)
#
# Now we have everyone in the database.

# %% [markdown]
# ### Save web page locally
#
# So we've got our target URL -- if we request that page, we get back some HTML containing all the data we'd like to scrape.
#
# When possible, it's good practice to save local copies of the pages that you're scraping. That way you don't have to rely on a stable internet connection as you work on your scraper, and you can avoid sending unneccessary traffic to the target's server.
#
# Let's do that now.
#
# First, set up a couple of variables:
# - The base URL
# - A [dictionary](../reference/Python%20data%20types%20and%20basic%20syntax.ipynb#Dictionaries) of URL parameters (see [the requests documentation here](http://docs.python-requests.org/en/master/user/quickstart/#passing-parameters-in-urls))
# - The name of the `.html` file we'll save to locally
# - The name of the `.csv` file we'll write out our results to

# %%
BASE_URL = 'http://www.openbookpittsburgh.com/SearchLobbyists.aspx'

URL_PARAMS = {
    'page': 0,
    'cat': 'LobbyistName',
    'sort': 'ASC',
    'num': 1000,
    'click': 1
}

HTML_FILE = 'pittsburgh-lobbyists.html'
CSV_FILE = 'pittsburgh-lobbyists.csv'

# %% [markdown]
# Now actually fetch the page, specifying our headers and `params=URL_PARAMS`.

# %%
r = requests.get(BASE_URL,
                 headers={'name': 'Cody Winchester', 'email': 'cody@ire.org'},
                 params=URL_PARAMS)

# %% [markdown]
# Write the `text` attribute -- the code underpinning the requested page -- to the file under the name we just specified.

# %%
with open(HTML_FILE, 'w') as o:
    o.write(r.text)

# %% [markdown]
# Great! Now we have a copy of the webpage in this directory. Let's open it up and turn the contents into a `BeautifulSoup` object.

# %%
with open(HTML_FILE, 'r') as i:
    soup = BeautifulSoup(i.read(), 'html.parser')

# %% [markdown]
# We're ready to start looking for patterns and isolating the HTML elements we want to target. I like to examine the source code in the browser (In Chrome, it's `Ctrl+U` on PCs and `Ctrl+option+U` on a Mac).
#
# It looks like all of the lobbyist HTML is enclosed in a `div` with the class `items-container`. Let's use the BeautifulSoup method `find` to isolate that first.

# %%
container = soup.find('div', {'class': 'items-container'})

# %% [markdown]
# Within that container, it looks like each individual entry is a `div` with the class `item`. Let's use `find_all` to return a list of matching elements within the container.
#
# Then we can use the built-in [`len()`](https://docs.python.org/3/library/functions.html#len) function to see how many we've got.

# %%
items = container.find_all('div', {'class': 'item'})

# %%
len(items)
# Out:
# 83

# %% [markdown]
# Looking good! Let's grab _one_ of those items as a test and parse out the information. We'll then use what we learned to scrape the info out of each entry, one at a time.
#
# Lobbyists have multiple clients, so in our database, one record will be one lobbying relationship -- each line is, essentially, a client and the lobbyist representing them.

# %%
# grab the first item and call it `test`
test = items[0]

# the person's name is in an h2 headline
name = test.find('h2').text.strip()

# their position is in a span element with the class `position`
position = test.find('span', {'class': 'position'}).text.strip()

# their status is in two span elements that have the class `position`
# the first is currency (expired or current)
# the second is, are they a lobbyist for the city?
# find_all() returns a list
statuses = test.find_all('span', {'class': 'status'})

# grab text of "currency" status tag
status = statuses[0].text.strip()

# set a default value -- they're assumed to not be a city lobbyist
lobbyist_for_city = False

# unless the word "yes" appears in the (lowercased) city lobbyist span text
# in which case, flip that variable to true
if 'yes' in statuses[1].text.lower():
    lobbyist_for_city = True

# the company is in a div with the class `type`
company = test.find('div', {'class': 'type'}).text.strip()

# the company address is in a div with the class `title`
company_address = test.find('div', {'class': 'title'}).text.strip()

# lobbyists can have one or more clients, and these are list items in an unordered list
# use find_all() to get all of the list items
clients = test.find_all('li')

# loop over the list of clients
for client in clients:
    
    # the company is in a span with the class `company`
    # we'll also strip off the colon at the end and kill any external whitespace
    # https://www.tutorialspoint.com/python/string_rstrip.htm
    client_company = client.find('span', {'class': 'company'}).string.rstrip(':').strip()
    
    # the company address is in a span with the class `address`
    client_address = client.find('span', {'class': 'address'}).string.strip()

    # use a trick to strip out internal whitespace
    # https://stackoverflow.com/a/3739939
    client_address_clean = ' '.join(client_address.split())
    
    # print the results
    print(name, position, status, lobbyist_for_city, company, company_address,
          client_company, client_address_clean)
# Out:
# Abass B. Kamara Partner expired False The Carey Group The Grant Bldg. 310 Grant Street Suite 1123 Pittsburgh PA, 15219 Veolia Water America LLC 200 East Randolph Street, Chicago IL, 60601
# Abass B. Kamara Partner expired False The Carey Group The Grant Bldg. 310 Grant Street Suite 1123 Pittsburgh PA, 15219 SEIU Healthcare Pennsylvania 1500 North Second Street, Harrisburg PA, 17102
# Abass B. Kamara Partner expired False The Carey Group The Grant Bldg. 310 Grant Street Suite 1123 Pittsburgh PA, 15219 American Traffic Solutions 1330 West Southern Avenue, Tempe AZ, 85282

# %% [markdown]
# Solid. Now we can basically copy-paste that code into a [for loop](../reference/Python%20data%20types%20and%20basic%20syntax.ipynb#for-loops) and apply it to each item we found.

# %%
for item in items:

    name = item.find('h2').text.strip()
    position = item.find('span', {'class': 'position'}).text.strip()
    statuses = item.find_all('span', {'class': 'status'})
    status = statuses[0].text.strip()

    lobbyist_for_city = False
    if 'yes' in statuses[1].text.lower():
        lobbyist_for_city = True

    company = item.find('div', {'class': 'type'}).text.strip()
    company_address = item.find('div', {'class': 'title'}).text.strip()

    clients = item.find_all('li')

    for client in clients:
        client_company = client.find('span', {'class': 'company'}).string.rstrip(':').strip()
        client_address = client.find('span', {'class': 'address'}).string.strip()
        
        client_address_clean = ' '.join(client_address.split())
        print(name, position, status, lobbyist_for_city, company, company_address,
              client_company, client_address_clean)
# Out:
# Abass B. Kamara Partner expired False The Carey Group The Grant Bldg. 310 Grant Street Suite 1123 Pittsburgh PA, 15219 Veolia Water America LLC 200 East Randolph Street, Chicago IL, 60601
# Abass B. Kamara Partner expired False The Carey Group The Grant Bldg. 310 Grant Street Suite 1123 Pittsburgh PA, 15219 SEIU Healthcare Pennsylvania 1500 North Second Street, Harrisburg PA, 17102
# Abass B. Kamara Partner expired False The Carey Group The Grant Bldg. 310 Grant Street Suite 1123 Pittsburgh PA, 15219 American Traffic Solutions 1330 West Southern Avenue, Tempe AZ, 85282
# Alexandra B. Kozak Mgr. of Gov and Community Relations current 2018 False Duquesne University 600 Forbes Avenue Pittsburgh PA, 15282 Duquesne University 600 Forbes Avenue, Pittsburgh PA, 15282
# Andrea Perez PA Political Director current 2018 False SEIU Local 32BJ 209 9th Floor  Pittsburgh PA, 15222 SEIU Local 32BJ 25 West 18th Street 5th Floor, New York NY, 10011
# Archie c. Buckner WPA Political Director current 2018 False SEIU Local 32BJ 209 9th Street 9th Floor Pittsburgh PA, 15222 SEIU Local 32BJ 25 West 18th Street 5th Floor, New York NY, 10011
# Ashley Henry Shook Grassroots Lobbying Director expired False Duane Morris Gov Strategies LLC 600 Grant Street Suite 5010 Pittsburgh PA, 15219 Xerox Business Services LLC and its Affiliates 1800 M Street NW NorthTower Suite 700, Washington DC, 20036
# Audrick K. Dodds Operations Manager/External Affairs expired False EQT Corporation 625 Liberty Avenue Suite 1700 Pittsburgh PA, 15222 EQT Corporation 625 Liberty Avenue Suite 1700, Pittsburgh PA, 15222
# Barbara K. Mistick President and Director expired False Carnegie Library of Pittsburgh 4400 Forbes Avenue Pittsburgh PA, 15213 Carnegie Library of Pittsburgh 4400 Forbes Avenue, Pittsburgh PA, 15213
# Barney Oursler Owner current 2018 False Self 6323 Douglas Street Pittsburgh PA, 15217 United Food and Commercial Workers 345 Southpointe Blvd Suite 300, Canonsburg PA, 15317
# Ben Price Projects Director expired False Community Environmental Legal Defense Fund 675 Mower Road Chambersburg PA, 17202 Community Environmental Legal Defense Fund 675 Mower Road, Chambersburg PA, 17207
# Brendan R. Schubert Associate current 2017 False Triad Strategies LLC 220 Grant Street 7th Floor Pittsburgh PA, 15219 NRP Group LLC 332 Woodbridge Avenue, Buffalo NY, 14214
# Brendan R. Schubert Associate current 2017 False Triad Strategies LLC 220 Grant Street 7th Floor Pittsburgh PA, 15219 Rebuilding Together Pittsburgh 7800 Susquehanna, Pittsburgh PA, 15208
# Brendan R. Schubert Associate current 2017 False Triad Strategies LLC 220 Grant Street 7th Floor Pittsburgh PA, 15219 Agile Network 213 Market Street Suite 310, Canton OH, 44702
# Brendan R. Schubert Associate current 2017 False Triad Strategies LLC 220 Grant Street 7th Floor Pittsburgh PA, 15219 Vitmore LP P.O. Box 9009, Pittsburgh PA, 15224
# Brendan R. Schubert Associate current 2017 False Triad Strategies LLC 220 Grant Street 7th Floor Pittsburgh PA, 15219 Pennsylvania Aqua America Inc. 762 W. Lancater Avenue, Bryn Mawr PA, 19010
# Brendan R. Schubert Associate current 2017 False Triad Strategies LLC 220 Grant Street 7th Floor Pittsburgh PA, 15219 Johnson Controls 5757 N. Green Bay Ave PO Box 591, Milwaukee WI, 53201
# Brendan R. Schubert Associate current 2017 False Triad Strategies LLC 220 Grant Street 7th Floor Pittsburgh PA, 15219 DTI Development Inc. 220 Grant Street 7th Floor, Pittsburgh PA, 15219
# Brendan R. Schubert Associate current 2017 False Triad Strategies LLC 220 Grant Street 7th Floor Pittsburgh PA, 15219 McCaffery Interests Inc. 875 North Michigan Avenue Ste 1800, Chicago IL, 60611
# Brian Hughes General Manager current 2018 False Uber Technologies 1455 Market Street Suite 400 San Francisco CA, 94103 Uber Technologies Inc. 1455 Market Street Suite 400, San Francisco CA, 94103
# Bruce A. Fletcher Sr. Executive Vice President expired False Chester Engineers 1555 Coraopolis Heights Road Moon Township PA, 15108 Chester Engineers 1555 Coraopolis Heights Road, Moon Township PA, 15108
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Port Authority of Allegheny County Heniz 57 Center 345 6th Avenue 3rd Floor, Pittsburgh PA, 15222
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Carnegie Library 4400 Forbes Avenue, Pittsburgh PA, 15222
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Histroical Society of Western PA 1212 Smallman Street, Pittsburgh PA, 15222
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Duquesne University 600 Forbes Avenue, Pittsburgh PA, 15282
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 L.R. Kimball and Associates 437 Grant Street, Pittsburgh PA, 15219
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Junior Achievement One Allegheny Center Suite 430, Pittsburgh PA, 15212
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Pittsburgh School District 341 S Bellefield Avenue, Pittsburgh PA, 15213
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Point Park University 201 Wood Street, Pittsburgh PA, 15222
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Pittsburgh Supercomputing 300 S. Craig Street, Pittsburgh PA, 15213
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Buchart Horn 2200 Liberty Avenue Suite 300, Pittsburgh PA, 15222
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Pittsburgh Cultural Trust 803 Liberty Avenue, Pittsburgh PA, 15222
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 BNY Mellon 500 Grant Street Suite 4045, Pittsburgh PA, 15258
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 ALCOA 201 Isabella Street, Pittsburgh PA, 15212
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Holdings Acquisition 777 Casino Drive, Pittsburgh PA, 15212
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 RIDC 210 Sixth Avenue #3620, Pittsburgh PA, 15222
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 The Children's Museum 10 Children's Way, Pittsburgh PA, 15212
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Community College of Allegheny County 800 Allegheny Avenue, Pittsburgh PA, 15233
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Pittsburgh Ballet Theatre 2900 Liberty Avenue, Pittsburgh PA, 15201
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Port of Pittsburgh 4955 Steubenville Pike Suite 245A, Pittsburgh PA, 15205
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Chatham University Woodland Road, Pittsburgh PA, 15232
# Charles J. Kolling, Jr. Government Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Centre 20th Floor Pittsburgh PA, 15219 Pittsburgh Parks Conservancy 45 S. 23rd Street #101, Pittsburgh PA, 15203
# Christina Walsh Manager Terminated False Institute for Justice 901 North Glebe Road Suite 900 Arlington VA, 22203 Institute for Jusitce 901 North Glebe Road Suite 900, Arlington VA, 22203
# David Caliguiri Sr. Government Affairs Manager expired False The Caliguri Group 1049 Highmont Road Pittsburgh PA, 15232 American Traffic Soultions Inc. 1330 West Southern Avenue Suite 101, Tempe AZ, 85282
# David Caliguiri Sr. Government Affairs Manager expired False The Caliguri Group 1049 Highmont Road Pittsburgh PA, 15232 Holdings Acquisition Co. LP d/b/a Rivers Casino 777 Casino Drive, Pittsburgh PA, 15212
# David Ira Samuel Sales Manager expired False Redflex Traffic Systems Inc. 23751 North 23rd Avenue Phoenix AZ, 85085 Redflex Traffic Systems Inc. 2351 North 23rd Avenue Suite 150, Phoenix AZ, 85085
# David Lauteri Sr. Gov Relations Rep current 2017 False Duquesne Light Company 411 Seventh Avenue Pittsburgh PA, 15219 Duquesne Light 411 Seventh Avenue, Pittsburgh PA, 15219
# David Ross Director of Business Development expired False EQT Corporation 625 Liberty Avenue Suite 1700 Pittsburgh PA, 15222 EQT Corporation 625 Liberty Avenue Suite 1700, Pittsburgh PA, 15222
# Dawn Marie Keezer Director current 2015 False Pittsburgh Film Office 130 7th Street Suite 202 Pittsburgh PA, 15222 Greater PGH Ofc of Prom dba PGH Film Office 130 7th Street Suite 202, Pittsburgh PA, 15222
# Dennis Herbert Troy President current 2018 False DTI Development Inc/DTI Advisory Group Inc. 220 Grant Street 7th Floor Pittsburgh PA, 15219 CDM Smith Inc. 503 Martindale Street Suite #500, Pittsburgh PA, 15212
# Dennis Herbert Troy President current 2018 False DTI Development Inc/DTI Advisory Group Inc. 220 Grant Street 7th Floor Pittsburgh PA, 15219 Cleopatra Resources LLC 129 West 29th Street Ste 600 N, New York NY, 10001
# Dennis Herbert Troy President current 2018 False DTI Development Inc/DTI Advisory Group Inc. 220 Grant Street 7th Floor Pittsburgh PA, 15219 Hammel Companies, Inc. 15 27th Street, Pittsburgh PA, 15222
# Dennis Herbert Troy President current 2018 False DTI Development Inc/DTI Advisory Group Inc. 220 Grant Street 7th Floor Pittsburgh PA, 15219 Int'l Brotherhood of Electrical Workers Local #5 5 Hot Metal Street, Pittsburgh PA, 15203
# Dennis Herbert Troy President current 2018 False DTI Development Inc/DTI Advisory Group Inc. 220 Grant Street 7th Floor Pittsburgh PA, 15219 Larson Desgin Group 8050 Rowan Rd Suite 504, Cranberry Twp PA, 16066
# Dennis Herbert Troy President current 2018 False DTI Development Inc/DTI Advisory Group Inc. 220 Grant Street 7th Floor Pittsburgh PA, 15219 MCM Company Inc. 1468 West 9th Street #125, Cleveland OH, 44113
# Dennis Herbert Troy President current 2018 False DTI Development Inc/DTI Advisory Group Inc. 220 Grant Street 7th Floor Pittsburgh PA, 15219 NRP Group LLC 5309 Transportation Blvd, Cleveland OH, 44125
# Dennis Herbert Troy President current 2018 False DTI Development Inc/DTI Advisory Group Inc. 220 Grant Street 7th Floor Pittsburgh PA, 15219 Steamfitters Local Union #449 1517 Woodruff Street, Pittsburgh PA, 15220
# Dennis Herbert Troy President current 2018 False DTI Development Inc/DTI Advisory Group Inc. 220 Grant Street 7th Floor Pittsburgh PA, 15219 North River Pittsburgh 1 LLC 224 12th Avenue, New York NY, 10001
# Dennis J. Simon Governmental Affairs expired False Chester Engineers 601 Grant Street Pittsburgh PA, 15219 Chester Engineers 1555 Coraopolis Heights Road, Moon Township PA, 15108
# Gabe Morgan PA State Director current 2018 False SEIU 32BJ 209 9th Street Pittsburgh PA, 15222 SEIU Local 32BJ 25 West 18th Street, 5th Floor, New York NY, 10011
# Gerald Michael Waites Partner current 2018 False O'Donoghue & O'Donoghue LLP 5301 Wisconsin Avenue NW Ste 800 Washington DC, 20015 Steamfitters Local Union #449 1517 Woodruff Street, Pittsburgh PA, 15220
# Heather Sage Director of Community Projects current 2018 False Pittsburgh Parks Conservancy 45 S. 23rd Street Ste.101 Pittsburgh PA, 15203 Pittsburgh Parks Conservancy 2000 Technology Drive Suite 200, Pittsburgh PA, 15219
# Jacqui Fiske Lazo Attorney expired False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Ctr 20th Floor Pittsburgh PA, 15219-1410 Holdings Acquisition Co., L.P. 900 North Michigan Avenue Suite 1900, Chicago IL, 60611
# Jacqui Fiske Lazo Attorney expired False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Ctr 20th Floor Pittsburgh PA, 15219-1410 Point Park University 201 Wood Street, Pittsburgh PA, 15222
# Jacqui Fiske Lazo Attorney expired False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Ctr 20th Floor Pittsburgh PA, 15219-1410 Pittsburgh Steelers Sports Inc. 3400 South Water Street, Pittsburgh PA, 15203
# James N. Williams III Director of Local Gov Relations current 2018 False University of Pittsburgh 4227 Fifth Avenue Suite 710 Pittsburgh PA, 15260 University of Pittsburgh 4227 Fifth Avenue Suite 710, Pittsburgh PA, 15260
# James Protin Vice President expired False Chester Engineers 601 Grant Street  Pittsburgh PA, 15219 Chester Engineers 601 Grant Street, Pittsburgh PA, 15219
# Jason P. Wrona Attorney expired False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Ctr 20th Floor Pittsburgh PA, 15219-1410 Holdings Acquisition Co. LP 900 North Michigan Avenue Suite 1900, Chicago IL, 60611
# Jason P. Wrona Attorney expired False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Ctr 20th Floor Pittsburgh PA, 15219-1410 Point Park University 201 Wood Street, Pittsburgh PA, 15222
# Jason P. Wrona Attorney expired False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Ctr 20th Floor Pittsburgh PA, 15219-1410 Pittsburgh Steelers Sports Inc. 3400 South Water Street, Pittsburgh PA, 15203
# Jennifer Cloonan Director of External and Gov Affairs current 2018 False Comcast Cable Communications Mgmt LLC 15 Summit Park Drive Pittsburgh PA, 15275 Comcast Corporation and Affiliated Entities 1701 JFK Blvd Office 49.421, Philadelphia PA, 19103
# Jennifer Meccariello Layman Assistant Director of Gov Relations expired False Carnegie Mellon University 425 Warner Hall 5000 Forbes Avenue Pittsburgh PA, 15213 Carnegie Mellon University 5000 Forbes Avenue, Pittsburgh PA, 15213
# Jennifer Rapach Poltical Coordinator expired False SEIU Local 32BJ 209 9th Street 9th Floor  Pittsburgh PA, 15222 SEIU Local 32BJ 209 9th Street, Pittsburgh PA, 15222
# Jeremy Wilson Deputy Political Director current 2016 False SEIU Local 32BJ 25 West 18th Street 5th Floor New York NY, 10011 SEIU Local 32BJ 25 West 18th Street 5th Floor, New York NY, 10011
# Jessi Pandolfo Project Coordinator expired False Greenlee Partners, LLC 601 Grant Street Suite 200 Pittsburgh PA, 15219 Redflex Traffic Systems Inc. 2351 North 23rd Avenue Suite 150, Phoenix AZ, 85085
# Jessi Pandolfo Project Coordinator expired False Greenlee Partners, LLC 601 Grant Street Suite 200 Pittsburgh PA, 15219 The Pittsburgh Film Office The Century Bldg. 130 7th St Suite 202, Pittsburgh PA, 15222
# Jessi Pandolfo Project Coordinator expired False Greenlee Partners, LLC 601 Grant Street Suite 200 Pittsburgh PA, 15219 Shallenberger Enterprise 195 Enterprise Lane, Connellsville PA, 15425
# John F. Malady Managing Partner current 2018 True Malady & Wooten LLP 604 North Third Street Harrisburg PA, 17101 Yellow Cab Company of Pittsburgh 1825 Liverpool Street, Pittsburgh PA, 15233
# John F. Malady Managing Partner current 2018 True Malady & Wooten LLP 604 North Third Street Harrisburg PA, 17101 Duquesne Light Company 411 Seventh Avenue, Pittsburgh PA, 15219
# John F. Malady Managing Partner current 2018 True Malady & Wooten LLP 604 North Third Street Harrisburg PA, 17101 Pittsburgh Symphony Orchestra 600 Penn Avenue, Pittsburgh PA, 15222
# John F. Malady Managing Partner current 2018 True Malady & Wooten LLP 604 North Third Street Harrisburg PA, 17101 Penn Film Group Suite #2 2820 Smallman Street, Pittsburgh PA, 15222
# John F. Malady Managing Partner current 2018 True Malady & Wooten LLP 604 North Third Street Harrisburg PA, 17101 Comcast Cable 1717 Langhorne Newtown Road, Langhorne PA, 19047
# John F. Malady Managing Partner current 2018 True Malady & Wooten LLP 604 North Third Street Harrisburg PA, 17101 Highmark Health PO Box 890600, Camp Hill PA, 17089
# John Paul Jones Government Relations expired False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Ctr. 20th Fl Pittsburgh PA, 15219 August Wilson Center 980 Libert Avenue, Pittsburgh PA, 15222
# John Paul Jones Government Relations expired False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Ctr. 20th Fl Pittsburgh PA, 15219 MinSec Companies 101 N. Providence Road, Wallingford PA, 19086
# Joseph Dawley Corporate Director, Government Affairs expired False EQT 625 Liberty Avenue Suite 1700 Pittsburgh PA, 15222 EQT Corporation 625 Liberty Avenue Suite 1700, Pittsburgh PA, 15222
# Joseph Divis Executive Director expired False AT&T; 200 N. Warner Road King of Prussia PA, 19406 AT&T; 1 AT&T; Way, Bedminster NJ, 07921
# Joseph Kuklis Managing Director expired False Duane Morris Gov Strategies LLC 600 Grant Street Suite 5010 Pittsburgh PA, 15219 Xerox Business Services LLC and its Affiliates 1800 M Street NW NorthTower Suite 700, Washington DC, 20036
# Joseph Martin Cusick Vice President Governmental Affairs expired False Chester Engineers 601 Grant Street Pittsburgh PA, 15219 Chester Engineers 601 Grant Street, Pittsburgh PA, 15219
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Citelum, 115 490 L'Enfant Plaza SW Suite 8214, Washington DC, 20004
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Post Authority of Allegheny County Heinz 57 Center, 345 Sixth Avenue 3rd Fl, Pittsburgh PA, 15222
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Carnegie Library of Pittsburgh 4400 Forbes Avenue, Pittsburgh PA, 15213
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Historical Society of Western PA 1212 Smallman Street, Pittsburgh PA, 15222
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Duquesne University 600 Forbes Avenue, Pittsburgh PA, 15282
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 L.R. Kimball & Associates 437 Grant Street, Pittsburgh PA, 15219
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Junior Achievement 5001 Centre Avenue #2 Fl, Pittsburgh PA, 15213
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Point Park University 201 Wood Street, Pittsburgh PA, 15222
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Pittsburgh Cultural Trust 803 Liberty Avenue, Pittsburgh PA, 15222
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 BNY Mellon 500 Grant Street Suite 4045, Pittsburgh PA, 15258
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 ALCOA 201 Isabella Street, Pittsburgh PA, 15212
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Holdings Acquisition 777 Casino Drive, Pittsburgh PA, 15212
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 RIDC 210 Sixth Avenue #3620, Pittsburgh PA, 15222
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Chatham University Woodland Road, Pittsburgh PA, 15232
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Buckart Horn 2200 Liberty Avenue Suite 300, Pittsburgh PA, 15222
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Pittsburgh School District 341 S. Bellefield Avenue, Pittsburgh PA, 15213
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Pittsburgh Supercomputing 300 S. Craig Street, Pittsburgh PA, 15213
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Pittsburgh Parks Conservancy 45 S. 23rd Street #101, Pittsburgh PA, 15203
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 The Children's Museum 10 Children's Way, Pittsburgh PA, 15212
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Community College of Allegheny County 800 Allegheny Avenue, Pittsburgh PA, 15233
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Pittsburgh Ballet Theatre 2900 Liberty Avenue, Pittsburgh PA, 15201
# Joseph Murzyn Lobbyist current 2018 True Self 503 Rosaire Drive Hummelstown PA, 17036 Port of Pittsburgh 4955 Steubenville Pike Suite 245A, Pittsburgh PA, 15205
# Karlyn A. Voss Director Office of External Gov Relations expired False Carnegie Library of Pittsburgh 4400 Forbes Avenue Pittsburgh PA, 15213 Carnegie Library of Pittsburgh 4400 Forbes Avenue, Pittsburgh PA, 15213
# Keith Tubbs Political Director expired False SEIU Local 32BJ 42 South 15th Street Pittsburgh PA, 19102 SEIU LOCAL 32BJ 25 WEST 18TH STREET 5TH FL, NEW YORK NY, 10011
# Kevin Fuller Deputy Director, Gov Affairs current 2016 False Bayer Corporation 6549 Braemar Avenue Noblesville IL, 46062 Bayer Corporation 100 Bayer Road, Pittsburgh PA, 15219
# Kevin Kerr Greenlight Manager current 2017 False Uber Technologies Inc. 5846 Ellsworth Avenue Pittsburgh PA, 15232 Uber Technologies Inc. 1455 Market Street Suite 400, San Francisco CA, 94103
# Kevin Kinross Owner expired False The Carey Group 310 Grant Street Suite 1123 Pittsburgh PA, 15219 Veolia Water America LLC 200 East Randolph Street Suite 7900, Chicago IL, 60601
# Kevin Kinross Owner expired False The Carey Group 310 Grant Street Suite 1123 Pittsburgh PA, 15219 Pittsburgh Penguins 1001 Fifth Avenue, Pittsburgh PA, 15219
# Kevin Kinross Owner expired False The Carey Group 310 Grant Street Suite 1123 Pittsburgh PA, 15219 SEIU Healthcare Pennsylvania 1500 North Second Street, Harrisburg PA, 17102
# Kevin Kinross Owner expired False The Carey Group 310 Grant Street Suite 1123 Pittsburgh PA, 15219 American Traffic Solutions 1330 West Southern Avenue, Tempe AZ, 85282
# Kimberly Hileman Government Affairs Manager current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 Greater Pittsburgh Chamber of Commerce 11 Stanwix Street 17th Floor, Pittsburgh PA, 15222
# Kimberly Hileman Government Affairs Manager current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 Walnut Capital Partners 5500 Walnut Street Suite 300, Pittsburgh PA, 15232
# Kimberly Hileman Government Affairs Manager current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 Sarah Heinz House Association One Heinz Street, Pittsburgh PA, 15212
# Kimberly Hileman Government Affairs Manager current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 Hill House Association 1835 Centre Avenue, Pittsburgh PA, 15219
# Kimberly Hileman Government Affairs Manager current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 McKnight Realty Partners 310 Grant Street, 17th Floor, Pittsburgh PA, 15219
# Kimberly Hileman Government Affairs Manager current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 Crow Hill Development 1000 Dean Street Ste 224, Brooklyn NY, 11238
# Kimberly Hileman Government Affairs Manager current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 UPMC US Steel Tower Suite 6242, Pittsburgh PA, 15219
# Kimberly Sokoloski Gov Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 409 N. Second Street Suite 500 Harrisburg PA, 17101 Philips 1050 K Street NW Suite 900, Washington DC, 20001
# Kimberly Sokoloski Gov Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 409 N. Second Street Suite 500 Harrisburg PA, 17101 Western Pennsylvania Conservancy 800 Waterfront Drive, Pittsburgh PA, 15222
# Kimberly Sokoloski Gov Relations Professional current 2018 True Buchanan Ingersoll & Rooney PC 409 N. Second Street Suite 500 Harrisburg PA, 17101 Philips 1050 K Street NW Suite 900, Washington DC, 20001
# Leslie Merrill McCombs Sr. Consultant Government Relations expired False UPMC 600 Grant Street Suite 6200 Pittsburgh PA, 15219 UPMC 600 Grant Street , Pittsburgh PA, 15219
# Lisa Birmingham Vice President, Gvt & Reg Affairs current 2018 False Comcast Cable Communications Mgmt. LLC 15 Summit Park Drive Pittsburgh PA, 15275 Comcast Corporation and Affiliated Entities 1701 JFK Blvd Office 49.421, Philadelphia PA, 19103
# Louie A. Lujan Government Relations Manager Current 2015 False Secureview 200 Public Square, Suite 2500 Cleveland OH, 44114 Secureview 200 Public Square, Suite 2500, Cleveland OH, 44114
# Marios Kritiotis Lobbyist current 2018 False Salvo Strategies LLC 320 Fort Duquesne Blvd Suite 140 Pittsburgh PA, 15222 Centene Corporation 7700 Forsyth Boulevard, St. Louis MO, 63105
# Marios Kritiotis Lobbyist current 2018 False Salvo Strategies LLC 320 Fort Duquesne Blvd Suite 140 Pittsburgh PA, 15222 PA Health & Wellness 5 Penn Center West, Pittsburgh PA, 15276
# Marios Kritiotis Lobbyist current 2018 False Salvo Strategies LLC 320 Fort Duquesne Blvd Suite 140 Pittsburgh PA, 15222 Zelenkofske Axlerod LLC 3800 McKnight East Ste 3805, Pittsburgh PA, 15237
# Mark J. Depretis VP, Gov & Reg Affairs current 2018 False Comcast Cable Communications Mgmt LLC 2994 Industrial Boulevard Bethel Park PA, 15102 Comcast Corporation and affiliated Entities 1701 JFK Blvd Ofc 49.421, Philadelphia PA, 19103
# Mary Ellen Solomon Director of Government Affairs current 2016 False Duquesne University 600 Forbes Avenue Pittsburgh PA, 15282 Duquesne University 600 Forbes Avenue, Pittsburgh PA, 15282
# Mary Frances Cooper President & Director expired False Carnegie Library of Pittsburgh 4400 Forbes Avenue Pittsburgh PA, 15213 Carnegie Library of Pittsburgh 4400 Forbes Avenue, Pittsburgh PA, 15213
# Megan Marie Block Western PA Political Coordinator expired False SEIU Local 32BJ 209 9th Street, 9th Floor Pittsburgh PA, 15222 SEIU Local 32BJ 101 Avenue of the Americas, New York NY, 10013
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Western PA Conservancy 800 Waterfront Drive, Pittsburgh PA, 15222
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 The Granite Building c/o Holly Brubach 2359 Railroad Street #3901, Pittsburgh PA, 15222
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Pittsburgh Supercomputing 300 S. Craig Street, Pittsburgh PA, 15213
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 L.R. Kimball and Associates 437 Grant Street , Pittsburgh PA, 15219
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Junior Achievement One Allegheny Center Suite 430, Pittsburgh PA, 15212
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 BNY Mellon 500 Grant Street Suite 4045, Pittsburgh PA, 15258
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Pittsburgh School District 341 S. Bellefield Avenue, Pittsburgh PA, 15213
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Point Park University 201 Wood Street, Pittsburgh PA, 15222
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Children's Museum 10 Children's Way, Pittsburgh PA, 15212
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Riverlife Task Force 707 Grant Street Suite 3500, Pittsburgh PA, 15219
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Carnegie Library 4400 Forbes Avenue, Pittsburgh PA, 15213
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Duquesne University 600 Forbes Avenue, Pittsburgh PA, 15282
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Historical Society of Western PA 1212 Smallman Street, Pittsburgh PA, 15213
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Port Authority of Allegheny County 345 Sixth Avenue Third Avenue, Pittsburgh PA, 15222
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Pittsburgh Supercomputing 300 S. Craig Street, Pittsburgh PA, 15213
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 ALCOA 201 Isabella Street, Pittsburgh PA, 15212
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Holdings Acquisition 777 Casino Drive, Pittsburgh PA, 15212
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 RIDC 210 Sixth Avenue #3620, Pittsburgh PA, 15222
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Parsons Transportation 100 M Street SE, Washington DC, 20003
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Pittsburgh Cultural Trust 803 Liberty Avenue, Pittsburgh PA, 15222
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Community College of Allegheny County 800 Allegheny Avenue, Pittsburgh PA, 15233
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Pittsburgh Ballet Theatre 2900 Liberty Avenue, Pittsburgh PA, 15201
# Meghan W. Fisher Government Relations Professional current 2017 False Buchanan Ingersoll & Rooney PC 301 Grant Street One Oxford Center 20th Fl Pittsburgh PA, 15212 Port of Pittsburgh 4955 Steubenville Pike Suite 245A, Pittsburgh PA, 15205
# Michael P. Pehur GSP Consulting Corp. expired False Development Services Manager 100 W. Station Square drive, Suite 500 Pittsburgh PA, 15219 Sycamore Grandview Development, Inc. 16807 South Park Ave, South Holland IL, 60473
# Michael P. Pehur GSP Consulting Corp. expired False Development Services Manager 100 W. Station Square drive, Suite 500 Pittsburgh PA, 15219 Burns & Scalo Real Estate Services Foster Plaza 9, 750 Holiday Dr., Suite 570, Greentree PA, 15220
# Michael P. Pehur GSP Consulting Corp. expired False Development Services Manager 100 W. Station Square drive, Suite 500 Pittsburgh PA, 15219 Elmhurst Group One Bigelow Square, Suite 630, Pittsburgh PA, 15219
# Michael P. Pehur GSP Consulting Corp. expired False Development Services Manager 100 W. Station Square drive, Suite 500 Pittsburgh PA, 15219 dck Worldwide, LLC 1900 State Route 51, Suite 200, Large PA, 15025
# Michelle Castro Director Government Relations expired False Duquesne University 600 Forbes Avenue Pittsburgh PA, 15282 Duquesne University 600 Forbes Avenue, Pittsburgh PA, 15282
# Nello Giorgetti Principal current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 Greater Pittsburgh Chamber of Commerce 11 Stanwix Street 17th Floor, Pittsburgh PA, 15222
# Nello Giorgetti Principal current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 Walnut Capital Partners 5500 Walnut Street Suite 300, Pittsburgh PA, 15232
# Nello Giorgetti Principal current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 Sarah Heinz House Association One Heinz Street, Pittsburgh PA, 15212
# Nello Giorgetti Principal current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 Hill House Association 1835 Centre Avenue, Pittsburgh PA, 15219
# Nello Giorgetti Principal current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 McKnight Realty Partners 310 Grant Street, 17th Floor, Pittsburgh PA, 15219
# Nello Giorgetti Principal current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 Crow Hill Development 1000 Dean Street, Ste 224, Brooklyn NY, 11238
# Nello Giorgetti Principal current 2018 False Cohen & Grigsby PC 625 Liberty Avenue Pittsburgh PA, 15222 UPMC US Steel Tower Ste 6242, Pittsburgh PA, 15219
# Nikkilia E. Lu Political Coordinator current 2017 False SEIU Local 32BJ 209 9th Street 9th Floor Pittsburgh PA, 15222 SEIU Local 32BJ 25 West 18th Street 5th Floor, New York NY, 10011
# Nina Tinari Director of Government Relations expired False S.R. Wojdak and Associates LP 200 South Broad Street, Suite 850 Philadelphia  PA, 19102 Microsoft Corporation 1 Microsoft Way, Redmond WA, 98052
# Patrick J. Lavelle Associate current 2018 True Malady & Wooten LLP 604 North Third Street Harrisburg PA, 17101 Duquesne Light Company 411 Seventh Avenue, Pittsburgh PA, 15219
# Patrick J. Lavelle Associate current 2018 True Malady & Wooten LLP 604 North Third Street Harrisburg PA, 17101 Yellow Cab Company of Pittsburgh 1825 Liverpool Street, Pittsburgh PA, 15233
# Patrick J. Lavelle Associate current 2018 True Malady & Wooten LLP 604 North Third Street Harrisburg PA, 17101 Pittsburgh Symphone Orchestra 600 Penn Avenue, Pittsburgh PA, 15222
# Patrick J. Lavelle Associate current 2018 True Malady & Wooten LLP 604 North Third Street Harrisburg PA, 17101 Penn Film Group Suite #2 2820 Smallman Street, Pittsburgh PA, 15222
# Patrick J. Lavelle Associate current 2018 True Malady & Wooten LLP 604 North Third Street Harrisburg PA, 17101 Comcast Cable 1717 Langhorne Newtown Road, Langhorne PA, 19047
# Patrick J. Lavelle Associate current 2018 True Malady & Wooten LLP 604 North Third Street Harrisburg PA, 17101 Highmark Health P.O. Box 890600, Camp Hill PA, 17089
# Paul A. Supowitz Vice Chancellor for Comm & Gov Relations current 2018 False University of Pittsburgh 4227 Fifth Avenue 710 Alumni Hall Pittsburgh PA, 15260 University of Pittsburgh 4200 Fifth Avenue, Pittsburgh PA, 15260
# Robert Cranmer Owner current 2018 False Cranmer Consultants 109 Dewalt Avenue Suite 201A Pittsburgh PA, 15227 McGann & Chester 700 Hardgrove Street, Pittsburgh PA, 15226
# Robert Frommer Governtment Affairs Terminated False Institute for Justice 901 N. Glebe Road Suite 900 Arlington VA, 22203 Institute for Justice 901 N. Glebe Rd Suite 900, Arlington VA, 22203
# Robert Jones Manager expired False Peoples Natural Gas 1201 Pitt Street Wilkinsburg PA, 15221 In Good Company P.O. Box 91372, Pittsburgh PA, 15221
# Robert Kennedy Vice President Govt Relations expired False UPMC US Steel Tower 600 Grant St 60th Fl Pittsburgh PA, 15219 UPMC 600 Grant Street, Pittsburgh PA, 15219
# Roy Wells President & Managing Director current 2017 False Triad Strategies 220 Grant Street, 7th Floor Pittsburgh PA, 15219 Johnson Controls 5757 N. Green Bay Avenue PO Box 591, Milwaukee WI, 53201
# Samuel B. Williamson Area Leader current 2018 False SEIU Local 32BJ 209 9th Street 10th Pittsburgh PA, 15222 SEIU Local 32BJ 25 West 18th Street 5th Floor, New York NY, 10011
# Shari Shapiro Head of Public Affairs current 2018 False Uber Technologies Inc. 114 S. 13th Street #3 Philadelphia PA, 19107 Uber Technologies Inc. 1455 Market Street Suite 400, San Francisco CA, 94103
# Stanley Rapp Partner current 2018 False Greenlee Partners LLC 601 Grant Street Suite 200 Pittsburgh PA, 15219 The Pittsburgh Film Office 130 7th Street Suite 202, Pittsburgh PA, 15222
# Stanley Rapp Partner current 2018 False Greenlee Partners LLC 601 Grant Street Suite 200 Pittsburgh PA, 15219 The Carnegie Institute d/b/a Carnegie Museums of 4400 Forbes Avenue, Pittsburgh PA, 15213
# Stanley Rapp Partner current 2018 False Greenlee Partners LLC 601 Grant Street Suite 200 Pittsburgh PA, 15219 Uber Technologies Inc. 1455 market Street 4th Floor, San Francisco CA, 94103
# Stephanie Pizzoferrato Deputy Director, State Govt Affairs current 2018 False Covestro LLC 601 Pennsylvania Ave Suite 235 South Washington DC, 20004 Covestro LLC 1 Covestro Circle, Pittsburgh PA, 15205
# Stephanie Wein Clean Water Advocate current 2018 False PennEnvironment 1429 Walnut Street Suite 1100 Philadelphia PA, 19102 PennEnvironment 1429 Walnut Street Suite 1100, Philadelphia PA, 19102
# Stephanie Wein Clean Water Advocate current 2018 False PennEnvironment 1429 Walnut Street Suite 1100 Philadelphia PA, 19102 PennEnvironment Research & Policy Center 1429 Walnut Street Suite 1100, Philadelphia PA, 19102
# Stephen Morgan Director of Development Services expired False GSP Consulting Corporation 100 W. Station Square Dr., Suite 500 Pittsburgh PA, 15219 DCK Worldwide 1900 State Route 51, Suite 200, Large PA, 15025
# Stephen Morgan Director of Development Services expired False GSP Consulting Corporation 100 W. Station Square Dr., Suite 500 Pittsburgh PA, 15219 Elmhurst Group One Bigelow Square, Suite 630, Pittsburgh PA, 15219
# Stephen Morgan Director of Development Services expired False GSP Consulting Corporation 100 W. Station Square Dr., Suite 500 Pittsburgh PA, 15219 Burns & Scalo Real Estate Services Foster Plaza 9, 750 Holiday Dr., Suite 570, Greentree PA, 15220
# Stephen Morgan Director of Development Services expired False GSP Consulting Corporation 100 W. Station Square Dr., Suite 500 Pittsburgh PA, 15219 Pittsburgh Allegheny Thermal 429 Fourth Ave, Suite 806, Pittsburgh PA, 15219
# Stephen Morgan Director of Development Services expired False GSP Consulting Corporation 100 W. Station Square Dr., Suite 500 Pittsburgh PA, 15219 Sycamore Grandview Development, Inc. 16807 South Park Ave, South Holland IL, 60473
# Suzanne Yenchko Director, Government Affairs expired False Pennsylvania American Water 800 West Hershey Park Drive Hershey PA, 17043 Pennsylvania American Water 800 West Hershey Park Drive, Hershey PA, 17043
# Terrence J. Murphy Partner expired False K&L; Gates LLP K&L; Gates Center 210 Sixth Avenue Pittsburgh PA, 15222 PA American Water Company 800 West HerseyPark Drive, Hersey PA, 17033
# Terrina Gogue Consultant expired False The Carey Group 310 Grant Street Suite 1123 Pittsburgh PA, 15219 Veolia Water America LLC 200 E. Randolph Street Suite 7900, Chicago IL, 60601
# Terrina Gogue Consultant expired False The Carey Group 310 Grant Street Suite 1123 Pittsburgh PA, 15219 Pittsburgh Penguins 1001 Fifth Avenue, Pittsburgh PA, 15219
# Terrina Gogue Consultant expired False The Carey Group 310 Grant Street Suite 1123 Pittsburgh PA, 15219 SEIU Healthcare Pennsylvania 3500 N. Second Street, Harrisburg PA, 17102
# Terrina Gogue Consultant expired False The Carey Group 310 Grant Street Suite 1123 Pittsburgh PA, 15219 American Traffic Solutions 1330 West Southern Avenue, Tempe AZ, 85282
# Timothy P. McNulty Assoc. Vice President for Governmental Relations expired False Carnegie Mellon University 426 Warner Hall 5000 Forbes Avenue Pittsburgh PA, 15213 Carnegie Mellon University 5000 Forbes Avenue, Pittsburgh PA, 15213
# Todd Eachus Senior Director Gvt & Reg Affairs current 2018 False Comcast Cable Communications Mgmt. LLC 1306 Goshen Parkway West Chester PA, 19380 Comcast Corporation and Affiliated Entities 1701 JFK Blvd Office 49.421, Philadelphia PA, 19103
# Vanessa DeSalvo Getz Owner current 2018 False Salvo Strategies LLC 320 Fort Duquesne Blvd Suite 140 Pittsburgh PA, 15222 Centene Corporation 7700 Forsyth Blvd., St. Louis MO, 63105
# Vanessa DeSalvo Getz Owner current 2018 False Salvo Strategies LLC 320 Fort Duquesne Blvd Suite 140 Pittsburgh PA, 15222 PA Health & Wellness 5 Penn Center West, Pittsburgh PA, 15276
# Vanessa DeSalvo Getz Owner current 2018 False Salvo Strategies LLC 320 Fort Duquesne Blvd Suite 140 Pittsburgh PA, 15222 Zelenkofske Axlerod LLC 3800 McKnight East Drive Ste 3805, Pitsburgh PA, 15237
# Vivian Li President and CEO current 2018 False Riverlife 707 Grant Street Pittsburgh PA, 15219 Riverlife 707 Grant Street Suite 3500, Pittsburgh PA, 15219
# Zachary Alan Barber Field Organizer current 2018 False PennEnvironment Inc. 1831 Murray Avenue Suite 219 Pittsburgh PA, 15217 PennEnvironment Inc. 1831 Murray Avenue Suite 219, Pittsburgh PA, 15217
# Zachary Alan Barber Field Organizer current 2018 False PennEnvironment Inc. 1831 Murray Avenue Suite 219 Pittsburgh PA, 15217 PennEnvironment Research & Policy Ctr 1831 Murray Avenue Suite 219, Pittsburgh PA, 15217
# Zachery Smith Associate current 2016 False Greenlee Partners LLC 600 Grant Street Suite 200 Pittsburgh PA, 15222 The Pittsburgh Film Office 130 7th Street Suite 202, Pittsburgh PA, 15222
# Zachery Smith Associate current 2016 False Greenlee Partners LLC 600 Grant Street Suite 200 Pittsburgh PA, 15222 The Carnegie Institute 4400 Forbes Avenue, Pittsburgh PA, 15213
# Zachery Smith Associate current 2016 False Greenlee Partners LLC 600 Grant Street Suite 200 Pittsburgh PA, 15222 Consol Energy 1000 Consol Energy Drive, Canonsburg PA, 15317

# %% [markdown]
# Looking good! Now let's write everything out to a CSV.

# %%
with open(CSV_FILE, 'w', newline='') as o:
    headers = ['name', 'position', 'status', 'city_lobbyist', 'company',
               'company_address', 'client_company', 'client_address']

    writer = csv.DictWriter(o, fieldnames=headers)
    writer.writeheader()
    
    for item in items:

        name = item.find('h2').text.strip()
        position = item.find('span', {'class': 'position'}).text.strip()
        statuses = item.find_all('span', {'class': 'status'})
        status = statuses[0].text.strip()

        lobbyist_for_city = False
        if 'yes' in statuses[1].text.lower():
            lobbyist_for_city = True

        company = item.find('div', {'class': 'type'}).text.strip()
        company_address = item.find('div', {'class': 'title'}).text.strip()

        clients = item.find_all('li')

        for client in clients:
            client_company = client.find('span', {'class': 'company'}).string.rstrip(':').strip()
            client_address = client.find('span', {'class': 'address'}).string.strip()

            client_address_clean = ' '.join(client_address.split())
            writer.writerow({
                'name': name,
                'position': position,
                'status': status,
                'city_lobbyist': lobbyist_for_city,
                'company': company,
                'company_address': company_address,
                'client_company': client_company,
                'client_address': client_address_clean
            })

# %% [markdown]
# ### _Extra credit_
#
# We're repeating ourselves a lot here. If I were going to publish this scraper, I'd probably clean this up into a series of functions that each do one thing. Some homework, if you're interested: Break down the processing we've done into major tasks (fetch the page, save to file, parse the contents) and write [functions](../reference/Functions.ipynb) for each task.
#
# (Eventually, as you progress in your coding journey, [this handy guide to refactoring](https://refactoring-101.readthedocs.io/en/latest/) will become very useful!.)

# %% [markdown]
# ### Load data into pandas for analysis
#
# Congrats! You've scraped a web page into a clean CSV. Here's where you could load it up into pandas and take a look.

# %%
df = pd.read_csv('pittsburgh-lobbyists.csv')

# %%
df.head()
# Out:
#                  name                             position        status  \
# 0     Abass B. Kamara                              Partner       expired
# 1     Abass B. Kamara                              Partner       expired
# 2     Abass B. Kamara                              Partner       expired
# 3  Alexandra B. Kozak  Mgr. of Gov and Community Relations  current 2018
# 4        Andrea Perez                PA Political Director  current 2018
#
#    city_lobbyist              company  \
# 0          False      The Carey Group
# 1          False      The Carey Group
# 2          False      The Carey Group
# 3          False  Duquesne University
# 4          False      SEIU Local 32BJ
#
#                                      company_address  \
# 0  The Grant Bldg. 310 Grant Street Suite 1123 Pi...
# 1  The Grant Bldg. 310 Grant Street Suite 1123 Pi...
# 2  The Grant Bldg. 310 Grant Street Suite 1123 Pi...
# 3             600 Forbes Avenue Pittsburgh PA, 15282
# 4                209 9th Floor  Pittsburgh PA, 15222
#
#                  client_company  \
# 0      Veolia Water America LLC
# 1  SEIU Healthcare Pennsylvania
# 2    American Traffic Solutions
# 3           Duquesne University
# 4               SEIU Local 32BJ
#
#                                       client_address
# 0        200 East Randolph Street, Chicago IL, 60601
# 1     1500 North Second Street, Harrisburg PA, 17102
# 2         1330 West Southern Avenue, Tempe AZ, 85282
# 3            600 Forbes Avenue, Pittsburgh PA, 15282
# 4  25 West 18th Street 5th Floor, New York NY, 10011

# %%
# what else?
