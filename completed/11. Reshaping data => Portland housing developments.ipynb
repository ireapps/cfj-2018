# %% [markdown]
# # Reshaping data: Portland housing developments
#
# In this notebook, we're going to work with some data on Portland (Oregon) housing developments since 2014. Right now, the data are scattered across a jillion spreadsheets. Our goal is to parse them all into one clean CSV. (Thanks to [Kelly Kenoyer of the Portland Mercury](https://twitter.com/Kelly_Kenoyer) for donating this data.)
#
# The spreadsheets, a mixture of `xls` and `xlsx` files, live in `../data/portland/`. A few things to note:
# - Some of the spreadsheets have extra columns
# - Some of the spreadsheets have other worksheets in addition to the data worksheet (pivot tables, mostly) -- but these are not always in the same position
# - Some of the spreadsheets have columns of mostly blank data that the city once used to manually aggregate data by category -- we don't want these columns
# - Some of the spreadsheets have blank rows
#
# Our strategy:
# - Get a list of Excel files in that directory using the [`glob`](https://docs.python.org/3/library/glob.html) module
# - Create an empty pandas data frame
# - Loop over the list of spreadsheet files and ...
#     - Read in the file to a data frame
#     - Find the correct worksheet
#     - Drop empty columns and rows
#     - Append to the main data frame
#
# First, we'll import `glob` and pandas.

# %%
import glob

import pandas as pd

# %% [markdown]
# Next, we'll use `glob` to get a list of the files we're going to loop over. We'll use the asterisk `*`, which means "match everything."

# %%
xl_files = glob.glob('../data/portland/*')

# %%
print(xl_files)
# Out:
# ['../data/portland/02_2017 new res units.xlsx', '../data/portland/04_2016 New Res Units.xls', '../data/portland/2018 01 New Residential Units - checked.xls', '../data/portland/03_2016 New Res Units.xls', '../data/portland/08_2014 New Res Units.xls', '../data/portland/2017 07 New Residential Units - checked.xls', '../data/portland/2017 08 New Residential Units - checked.xls', '../data/portland/2018 02 New Residential Units - checked.xls', '../data/portland/04_2015 New Res Units.xlsx', '../data/portland/2017 11 New Residential Units - checked.xls', '../data/portland/10_2016 new res units.xlsx', '../data/portland/08_2015 New Res Units.xlsx', '../data/portland/07_2015 New Res Units.xlsx', '../data/portland/05_2017 new res units.xls', '../data/portland/2018 05 New Residential Units - updated.xls', '../data/portland/01_2016 New Res Units.xls', '../data/portland/09_2014 New Res Units.xls', '../data/portland/12_2014 New Res Units.xlsx', '../data/portland/02_2016 New Res Units.xls', '../data/portland/2017 12 New Residential Units - checked.xls', '../data/portland/06_2017 new res units.xls', '../data/portland/03_2015 New Res Units.xlsx', '../data/portland/11_2015 New Res Units 2.xls', '../data/portland/07_2016 new res units.xlsx', '../data/portland/08_2016 new res units.xlsx', '../data/portland/01_2017 new res units.xlsx', '../data/portland/07_2014 New Res Units.xls', '../data/portland/2018 04 New Residential Units - checked.xls', '../data/portland/05_2015 New Res Units.xlsx', '../data/portland/12_2016 new res units.xlsx', '../data/portland/11_2014 New Res Units.xls', '../data/portland/2018 03 New Residential Units - checked.xls', '../data/portland/03_2017 new res units.xlsx', '../data/portland/05_2016 New Res Units.xlsx', '../data/portland/2017 09 New Residential Units - checked.xls', '../data/portland/12_2015 New Res Units.xls', '../data/portland/09_2016 new res units.xlsx', '../data/portland/06_2016 New Res Units.xlsx', '../data/portland/2017 10 New Residential Units - checked.xls', '../data/portland/2018 06 New Residential Units - checked.xls', '../data/portland/10_2014 New Res Units.xls', '../data/portland/02_2015 New Res Units.xlsx', '../data/portland/04_2017 new res units.xlsx', '../data/portland/06_2015 New Res Units.xlsx', '../data/portland/10_2015 New Res Units.xls', '../data/portland/09_2015 New Res Units.xlsx', '../data/portland/11_2016 new res units.xlsx']

# %% [markdown]
# Now we'll create an empty data frame. This will be the container we stuff the data into as we loop over the files.

# %%
housing = pd.DataFrame()

# %% [markdown]
# Let's take a look at what we're dealing with. We're going to loop over the spreadsheet, and for each one, we're going to look at:
# - The names of the worksheets in that spreadsheet
# - The columns in each worksheet
#
# This will help us decide, later, which worksheets we need to target.
#
# We're going to take advantage of the fact, [according to the `read_excel()` documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html), that you can pass `None` as the `sheet_names` argument and pandas will read in _all_ of the sheets as a big dictionary -- the keys are the names of the worksheets, the values are the associated data frames.
#
# Later, our logic will go like this:
# - Read in every worksheet as a data frame
# - Target the worksheet whose name matches the pattern for the data we need
#
# 👉 For a refresher on _for loops_ and dictionaries, [check out this notebook](../reference/Python%20data%20types%20and%20basic%20syntax.ipynb#for-loops).

# %%
# loop over the excel file paths
for f in xl_files:
    
    # load the file into a data frame
    # specifying `None` as the sheet name
    df = pd.read_excel(f, sheet_name=None)
    
    # print the name of the file
    print(f)
    
    # print the worksheet names
    print(df.keys())
    
    # print a divider to make scanning easier
    print('='*60)
    
    # and an empty line
    print('')
# Out:
# ../data/portland/02_2017 new res units.xlsx
# odict_keys(['Mercantile units', 'Sheet1', 'nrs'])
# ============================================================
#
# ../data/portland/04_2016 New Res Units.xls
# odict_keys(['Sheet2', 'PIVOT', '04_2016 New Res Units'])
# ============================================================
#
# ../data/portland/2018 01 New Residential Units - checked.xls
# odict_keys(['Summary', '2018 01 New Residential Units'])
# ============================================================
#
# ../data/portland/03_2016 New Res Units.xls
# odict_keys(['pivot', '03_2016 New Res Units'])
# ============================================================
#
# ../data/portland/08_2014 New Res Units.xls
# odict_keys(['08_2014 New Res Units'])
# ============================================================
#
# ../data/portland/2017 07 New Residential Units - checked.xls
# odict_keys(['Sheet1', '2017 07 New Residential Units'])
# ============================================================
#
# ../data/portland/2017 08 New Residential Units - checked.xls
# odict_keys(['Sheet1', '2017 08 New Residential Units'])
# ============================================================
#
# ../data/portland/2018 02 New Residential Units - checked.xls
# odict_keys(['Sheet1', '2018 02 New Residential Units'])
# ============================================================
#
# ../data/portland/04_2015 New Res Units.xlsx
# odict_keys(['Sheet1', '04_2015 New Res Units'])
# ============================================================
#
# ../data/portland/2017 11 New Residential Units - checked.xls
# odict_keys(['Sheet1', '2017 11 New Residential Units'])
# ============================================================
#
# ../data/portland/10_2016 new res units.xlsx
# odict_keys(['Sheet2', 'Sheet1', '10_2016 new res units'])
# ============================================================
#
# ../data/portland/08_2015 New Res Units.xlsx
# odict_keys(['08_2015 New Res Units', 'Pivot'])
# ============================================================
#
# ../data/portland/07_2015 New Res Units.xlsx
# odict_keys(['Sheet1', '07_2015 New Res Units'])
# ============================================================
#
# ../data/portland/05_2017 new res units.xls
# odict_keys(['Sheet1', '05_2017 new res units'])
# ============================================================
#
# ../data/portland/2018 05 New Residential Units - updated.xls
# odict_keys(['Sheet1', '2018 05 New Residential Units'])
# ============================================================
#
# ../data/portland/01_2016 New Res Units.xls
# odict_keys(['PIVOT', '01_2016 New Res Units'])
# ============================================================
#
# ../data/portland/09_2014 New Res Units.xls
# odict_keys(['09_2014 New Res Units'])
# ============================================================
#
# ../data/portland/12_2014 New Res Units.xlsx
# odict_keys(['Sheet1', '12_2014 New Res Units'])
# ============================================================
#
# ../data/portland/02_2016 New Res Units.xls
# odict_keys(['PIVOT', '02_2016 New Res Units'])
# ============================================================
#
# ../data/portland/2017 12 New Residential Units - checked.xls
# odict_keys(['Sheet1', '2017 12 New Residential Units'])
# ============================================================
#
# ../data/portland/06_2017 new res units.xls
# odict_keys(['Sheet1', '06_2017 new res units'])
# ============================================================
#
# ../data/portland/03_2015 New Res Units.xlsx
# odict_keys(['Sheet1', '03_2015 New Res Units'])
# ============================================================
#
# ../data/portland/11_2015 New Res Units 2.xls
# odict_keys(['Sheet1', '11_2015 New Res Units'])
# ============================================================
#
# ../data/portland/07_2016 new res units.xlsx
# odict_keys(['Sheet1', '07_2016 new res units'])
# ============================================================
#
# ../data/portland/08_2016 new res units.xlsx
# odict_keys(['Sheet1', '08_2016 new res units'])
# ============================================================
#
# ../data/portland/01_2017 new res units.xlsx
# odict_keys(['Sheet1', '01_2017 new res units'])
# ============================================================
#
# ../data/portland/07_2014 New Res Units.xls
# odict_keys(['07_2014 New Res Units'])
# ============================================================
#
# ../data/portland/2018 04 New Residential Units - checked.xls
# odict_keys(['Sheet1', '2018 04 New Residential Units'])
# ============================================================
#
# ../data/portland/05_2015 New Res Units.xlsx
# odict_keys(['Sheet1', '05_2015 New Res Units'])
# ============================================================
#
# ../data/portland/12_2016 new res units.xlsx
# odict_keys(['Sheet1', '12_2016 new res units'])
# ============================================================
#
# ../data/portland/11_2014 New Res Units.xls
# odict_keys(['Sheet1', '11_2014 New Res Units'])
# ============================================================
#
# ../data/portland/2018 03 New Residential Units - checked.xls
# odict_keys(['Sheet1', '2018 03 New Residential Units'])
# ============================================================
#
# ../data/portland/03_2017 new res units.xlsx
# odict_keys(['Sheet1', '03_2017 new res units'])
# ============================================================
#
# ../data/portland/05_2016 New Res Units.xlsx
# odict_keys(['Pivot', '05_2016 New Res Units'])
# ============================================================
#
# ../data/portland/2017 09 New Residential Units - checked.xls
# odict_keys(['Sheet1', '2017 09 New Residential Units'])
# ============================================================
#
# ../data/portland/12_2015 New Res Units.xls
# odict_keys(['Sheet1', '12_2015 New Res Units 2'])
# ============================================================
#
# ../data/portland/09_2016 new res units.xlsx
# odict_keys(['Sheet2', 'Sheet1', '09_2016 new res units'])
# ============================================================
#
# ../data/portland/06_2016 New Res Units.xlsx
# odict_keys(['Sheet2', 'Sheet1', '06_2016 New Res Units'])
# ============================================================
#
# ../data/portland/2017 10 New Residential Units - checked.xls
# odict_keys(['Sheet1', '2017 10 New Residential Units'])
# ============================================================
#
# ../data/portland/2018 06 New Residential Units - checked.xls
# odict_keys(['Sheet1', '2018 06 New Residential Units'])
# ============================================================
#
# ../data/portland/10_2014 New Res Units.xls
# odict_keys(['10_2014 New Res Units'])
# ============================================================
#
# ../data/portland/02_2015 New Res Units.xlsx
# odict_keys(['Sheet1', '02_2015 New Res Units'])
# ============================================================
#
# ../data/portland/04_2017 new res units.xlsx
# odict_keys(['Sheet1', '04_2017 new res units'])
# ============================================================
#
# ../data/portland/06_2015 New Res Units.xlsx
# odict_keys(['Sheet1', '06_2015 New Res Units'])
# ============================================================
#
# ../data/portland/10_2015 New Res Units.xls
# odict_keys(['Sheet1', '10_2015 New Res Units'])
# ============================================================
#
# ../data/portland/09_2015 New Res Units.xlsx
# odict_keys(['09_2015 LUS stats'])
# ============================================================
#
# ../data/portland/11_2016 new res units.xlsx
# odict_keys(['Sheet1', '11_2016 new res units'])
# ============================================================

# %% [markdown]
# OK. So it looks like our target sheets are called a few different things: `nrs`, `04_2016 New Res Units'`, `'2018 04 New Residential Units'`, etc.
#
# Can we come up with a list of patterns to match all of them? I think we can.

# %%
# the items in this list are lowercased,
# because we're gonna match on .lower()'d versions of the sheet names
target_sheet_name_fragments = ['new res', 'nrs', 'lus stats']

# %% [markdown]
# So now, we need to write some logic that says: Pick the worksheet that has one of our `target_sheet_name_fragments` in the name. A nested pair of _for loops_ will do the trick for us.

# %%
# loop over the excel file paths
for f in xl_files:
    
    # load the file into a data frame
    # specifying `None` as the sheet name
    df = pd.read_excel(f, sheet_name=None)
        
    # start off with no match
    match = None
    
    # loop over the worksheet names
    for ws_name in df.keys():
        
        # loop over the word fragments
        for fragment in target_sheet_name_fragments:
            
            # if this fragment exists in the lowercased worksheet name
            if fragment in ws_name.lower():
                
                # we've got a winner
                match = ws_name
    
    # if, when we get to the end of this, `match` is still None
    if not match:
        # print something to let us know about it
        print(f'NO MATCH FOUND FOR {f}')
        
        # and the names of the sheets
        print(df.keys())
        
        # and break out of the loop
        break
    
    # otherwise, grab a handle to the worksheet we want
    working_df = df[match]
    
    # print a status message to let us know what's up
    print(f'parsing "{match}" worksheet from "{f}"')
# Out:
# parsing "nrs" worksheet from "../data/portland/02_2017 new res units.xlsx"
# parsing "04_2016 New Res Units" worksheet from "../data/portland/04_2016 New Res Units.xls"
# parsing "2018 01 New Residential Units" worksheet from "../data/portland/2018 01 New Residential Units - checked.xls"
# parsing "03_2016 New Res Units" worksheet from "../data/portland/03_2016 New Res Units.xls"
# parsing "08_2014 New Res Units" worksheet from "../data/portland/08_2014 New Res Units.xls"
# parsing "2017 07 New Residential Units" worksheet from "../data/portland/2017 07 New Residential Units - checked.xls"
# parsing "2017 08 New Residential Units" worksheet from "../data/portland/2017 08 New Residential Units - checked.xls"
# parsing "2018 02 New Residential Units" worksheet from "../data/portland/2018 02 New Residential Units - checked.xls"
# parsing "04_2015 New Res Units" worksheet from "../data/portland/04_2015 New Res Units.xlsx"
# parsing "2017 11 New Residential Units" worksheet from "../data/portland/2017 11 New Residential Units - checked.xls"
# parsing "10_2016 new res units" worksheet from "../data/portland/10_2016 new res units.xlsx"
# parsing "08_2015 New Res Units" worksheet from "../data/portland/08_2015 New Res Units.xlsx"
# parsing "07_2015 New Res Units" worksheet from "../data/portland/07_2015 New Res Units.xlsx"
# parsing "05_2017 new res units" worksheet from "../data/portland/05_2017 new res units.xls"
# parsing "2018 05 New Residential Units" worksheet from "../data/portland/2018 05 New Residential Units - updated.xls"
# parsing "01_2016 New Res Units" worksheet from "../data/portland/01_2016 New Res Units.xls"
# parsing "09_2014 New Res Units" worksheet from "../data/portland/09_2014 New Res Units.xls"
# parsing "12_2014 New Res Units" worksheet from "../data/portland/12_2014 New Res Units.xlsx"
# parsing "02_2016 New Res Units" worksheet from "../data/portland/02_2016 New Res Units.xls"
# parsing "2017 12 New Residential Units" worksheet from "../data/portland/2017 12 New Residential Units - checked.xls"
# parsing "06_2017 new res units" worksheet from "../data/portland/06_2017 new res units.xls"
# parsing "03_2015 New Res Units" worksheet from "../data/portland/03_2015 New Res Units.xlsx"
# parsing "11_2015 New Res Units" worksheet from "../data/portland/11_2015 New Res Units 2.xls"
# parsing "07_2016 new res units" worksheet from "../data/portland/07_2016 new res units.xlsx"
# parsing "08_2016 new res units" worksheet from "../data/portland/08_2016 new res units.xlsx"
# parsing "01_2017 new res units" worksheet from "../data/portland/01_2017 new res units.xlsx"
# parsing "07_2014 New Res Units" worksheet from "../data/portland/07_2014 New Res Units.xls"
# parsing "2018 04 New Residential Units" worksheet from "../data/portland/2018 04 New Residential Units - checked.xls"
# parsing "05_2015 New Res Units" worksheet from "../data/portland/05_2015 New Res Units.xlsx"
# parsing "12_2016 new res units" worksheet from "../data/portland/12_2016 new res units.xlsx"
# parsing "11_2014 New Res Units" worksheet from "../data/portland/11_2014 New Res Units.xls"
# parsing "2018 03 New Residential Units" worksheet from "../data/portland/2018 03 New Residential Units - checked.xls"
# parsing "03_2017 new res units" worksheet from "../data/portland/03_2017 new res units.xlsx"
# parsing "05_2016 New Res Units" worksheet from "../data/portland/05_2016 New Res Units.xlsx"
# parsing "2017 09 New Residential Units" worksheet from "../data/portland/2017 09 New Residential Units - checked.xls"
# parsing "12_2015 New Res Units 2" worksheet from "../data/portland/12_2015 New Res Units.xls"
# parsing "09_2016 new res units" worksheet from "../data/portland/09_2016 new res units.xlsx"
# parsing "06_2016 New Res Units" worksheet from "../data/portland/06_2016 New Res Units.xlsx"
# parsing "2017 10 New Residential Units" worksheet from "../data/portland/2017 10 New Residential Units - checked.xls"
# parsing "2018 06 New Residential Units" worksheet from "../data/portland/2018 06 New Residential Units - checked.xls"
# parsing "10_2014 New Res Units" worksheet from "../data/portland/10_2014 New Res Units.xls"
# parsing "02_2015 New Res Units" worksheet from "../data/portland/02_2015 New Res Units.xlsx"
# parsing "04_2017 new res units" worksheet from "../data/portland/04_2017 new res units.xlsx"
# parsing "06_2015 New Res Units" worksheet from "../data/portland/06_2015 New Res Units.xlsx"
# parsing "10_2015 New Res Units" worksheet from "../data/portland/10_2015 New Res Units.xls"
# parsing "09_2015 LUS stats" worksheet from "../data/portland/09_2015 New Res Units.xlsx"
# parsing "11_2016 new res units" worksheet from "../data/portland/11_2016 new res units.xlsx"

# %% [markdown]
# Scanning through that list, I feel comfortable that we're grabbing the correct data. Let's take a look at the columns in each worksheet we'll be parsing.

# %%
# loop over the excel file paths
for f in xl_files:
    
    # load the file into a data frame
    # specifying `None` as the sheet name
    df = pd.read_excel(f, sheet_name=None)
        
    # start off with no match
    match = None
    
    # loop over the worksheet names
    for ws_name in df.keys():
        
        # loop over the word fragments
        for fragment in target_sheet_name_fragments:
            
            # if this fragment exists in the lowercased worksheet name
            if fragment in ws_name.lower():
                
                # we've got a winner
                match = ws_name
    
    # if, when we get to the end of this, `match` is still None
    if not match:
        # print something to let us know about it
        print(f'NO MATCH FOUND FOR {f}')
        
        # and the names of the sheets
        print(df.keys())
        
        # and break out of the loop
        break
    
    # otherwise, grab a handle to the worksheet we want
    working_df = df[match]
    
    # print a status message to let us know what's up
    print(f'parsing "{match}" worksheet from "{f}"')
    
    # print a sorted list of column names
    print(sorted(working_df.columns))
    
    # print a divider to make scanning our results easier
    print('='*60)
    
    # print an empty line
    print()
# Out:
# parsing "nrs" worksheet from "../data/portland/02_2017 new res units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "04_2016 New Res Units" worksheet from "../data/portland/04_2016 New Res Units.xls"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "2018 01 New Residential Units" worksheet from "../data/portland/2018 01 New Residential Units - checked.xls"
# ['applicant_name', 'architect_names', 'const', 'folder', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "03_2016 New Res Units" worksheet from "../data/portland/03_2016 New Res Units.xls"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "08_2014 New Res Units" worksheet from "../data/portland/08_2014 New Res Units.xls"
# ['Unnamed: 4', 'Unnamed: 6', 'applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "2017 07 New Residential Units" worksheet from "../data/portland/2017 07 New Residential Units - checked.xls"
# ['applicant_name', 'architect_names', 'const', 'folder', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "2017 08 New Residential Units" worksheet from "../data/portland/2017 08 New Residential Units - checked.xls"
# ['applicant_name', 'architect_names', 'const', 'folder', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "2018 02 New Residential Units" worksheet from "../data/portland/2018 02 New Residential Units - checked.xls"
# ['applicant_name', 'architect_names', 'const', 'folder', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "04_2015 New Res Units" worksheet from "../data/portland/04_2015 New Res Units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "2017 11 New Residential Units" worksheet from "../data/portland/2017 11 New Residential Units - checked.xls"
# ['applicant_name', 'architect_names', 'const', 'folder', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "10_2016 new res units" worksheet from "../data/portland/10_2016 new res units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "08_2015 New Res Units" worksheet from "../data/portland/08_2015 New Res Units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "07_2015 New Res Units" worksheet from "../data/portland/07_2015 New Res Units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "05_2017 new res units" worksheet from "../data/portland/05_2017 new res units.xls"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "2018 05 New Residential Units" worksheet from "../data/portland/2018 05 New Residential Units - updated.xls"
# ['applicant_name', 'architect_names', 'const', 'folder', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "01_2016 New Res Units" worksheet from "../data/portland/01_2016 New Res Units.xls"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "09_2014 New Res Units" worksheet from "../data/portland/09_2014 New Res Units.xls"
# ['Unnamed: 4', 'Unnamed: 6', 'applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "12_2014 New Res Units" worksheet from "../data/portland/12_2014 New Res Units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "02_2016 New Res Units" worksheet from "../data/portland/02_2016 New Res Units.xls"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "2017 12 New Residential Units" worksheet from "../data/portland/2017 12 New Residential Units - checked.xls"
# ['applicant_name', 'architect_names', 'const', 'folder', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "06_2017 new res units" worksheet from "../data/portland/06_2017 new res units.xls"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
# parsing "03_2015 New Res Units" worksheet from "../data/portland/03_2015 New Res Units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "11_2015 New Res Units" worksheet from "../data/portland/11_2015 New Res Units 2.xls"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "07_2016 new res units" worksheet from "../data/portland/07_2016 new res units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "08_2016 new res units" worksheet from "../data/portland/08_2016 new res units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "01_2017 new res units" worksheet from "../data/portland/01_2017 new res units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "07_2014 New Res Units" worksheet from "../data/portland/07_2014 New Res Units.xls"
# ['Unnamed: 4', 'Unnamed: 6', 'applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "2018 04 New Residential Units" worksheet from "../data/portland/2018 04 New Residential Units - checked.xls"
# ['applicant_name', 'architect_names', 'const', 'folder', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "05_2015 New Res Units" worksheet from "../data/portland/05_2015 New Res Units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "12_2016 new res units" worksheet from "../data/portland/12_2016 new res units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "11_2014 New Res Units" worksheet from "../data/portland/11_2014 New Res Units.xls"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "2018 03 New Residential Units" worksheet from "../data/portland/2018 03 New Residential Units - checked.xls"
# ['applicant_name', 'architect_names', 'const', 'folder', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "03_2017 new res units" worksheet from "../data/portland/03_2017 new res units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "05_2016 New Res Units" worksheet from "../data/portland/05_2016 New Res Units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "2017 09 New Residential Units" worksheet from "../data/portland/2017 09 New Residential Units - checked.xls"
# ['applicant_name', 'architect_names', 'const', 'folder', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "12_2015 New Res Units 2" worksheet from "../data/portland/12_2015 New Res Units.xls"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "09_2016 new res units" worksheet from "../data/portland/09_2016 new res units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "06_2016 New Res Units" worksheet from "../data/portland/06_2016 New Res Units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "2017 10 New Residential Units" worksheet from "../data/portland/2017 10 New Residential Units - checked.xls"
# ['applicant_name', 'architect_names', 'const', 'folder', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "2018 06 New Residential Units" worksheet from "../data/portland/2018 06 New Residential Units - checked.xls"
# ['applicant_name', 'architect_names', 'const', 'folder', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "10_2014 New Res Units" worksheet from "../data/portland/10_2014 New Res Units.xls"
# ['Unnamed: 4', 'Unnamed: 6', 'applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
# parsing "02_2015 New Res Units" worksheet from "../data/portland/02_2015 New Res Units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "04_2017 new res units" worksheet from "../data/portland/04_2017 new res units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "06_2015 New Res Units" worksheet from "../data/portland/06_2015 New Res Units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "10_2015 New Res Units" worksheet from "../data/portland/10_2015 New Res Units.xls"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "09_2015 LUS stats" worksheet from "../data/portland/09_2015 New Res Units.xlsx"
# ['Unnamed: 4', 'Unnamed: 6', 'applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================
#
# parsing "11_2016 new res units" worksheet from "../data/portland/11_2016 new res units.xlsx"
# ['applicant_name', 'architect_names', 'const', 'folder_desc', 'foldernumber', 'folderrsn', 'indate', 'issuedate', 'legaldesc', 'logged', 'new_units', 'occ', 'owner_names', 'project_name', 'prop_address', 'propertyroll', 'propgisid1', 'proplot', 'propplan', 'proptownship', 'rev', 'sqft', 'status', 'sub', 'valuation', 'workdesc']
# ============================================================

# %% [markdown]
# I notice that some columns are, e.g. `Unnamed: 4`. That means there's no column header. Let's take a look at one of those:

# %%
test = pd.read_excel('../data/portland/08_2014 New Res Units.xls', sheet_name='08_2014 New Res Units')

# %%
test.head(20)
# Out:
#            foldernumber                     prop_address  \
# 0   14-164434-000-00-RS        4215 NE 20TH AVE - Unit B
# 1   14-170323-000-00-RS               6453 SE RAYMOND ST
# 2   14-121509-000-00-RS                   1610 SE ASH ST
# 3   14-175678-000-00-RS        4626 NE 31ST AVE - Unit B
# 4   14-180679-000-00-RS        6120 NE 22ND AVE - Unit B
# 5   14-199311-000-00-RS        3019 SE 21ST AVE - Unit B
# 6   12-203807-000-00-RS        5324 NE 28TH AVE - Unit B
# 7   14-160745-000-00-RS  2116 NE ROSA PARKS WAY - Unit B
# 8   14-192361-000-00-RS        5716 NE 32ND AVE - Unit B
# 9                   NaN                              NaN
# 10  14-152153-000-00-CO                 1475 SE 15TH AVE
# 11  14-147628-000-00-CO                2640 SE ANKENY ST
# 12                  NaN                              NaN
# 13  14-123577-000-00-RS                  914 SE 28TH AVE
# 14  13-201163-000-00-RS             7111 N GREENWICH AVE
# 15  14-150896-000-00-RS                 6027 NE 27TH AVE
# 16  14-103432-000-00-RS               7928 N BURRAGE AVE
# 17  14-174652-000-00-RS              3764 SE STEPHENS ST
# 18  13-201303-000-00-RS                10810 SW 61ST AVE
# 19  14-160625-000-00-RS                1720 NE 155TH AVE
#
#                                     sub  new_units  Unnamed: 4  valuation  \
# 0               Accessory Dwelling Unit        1.0         NaN    35734.0
# 1               Accessory Dwelling Unit        1.0         NaN    89517.0
# 2               Accessory Dwelling Unit        1.0         NaN    55240.0
# 3               Accessory Dwelling Unit        1.0         NaN    48969.0
# 4               Accessory Dwelling Unit        1.0         NaN    35624.0
# 5               Accessory Dwelling Unit        1.0         NaN     3000.0
# 6               Accessory Dwelling Unit        1.0         NaN    78979.0
# 7               Accessory Dwelling Unit        1.0         NaN    55145.0
# 8               Accessory Dwelling Unit        1.0         9.0    18013.0
# 9                                   NaN        NaN         NaN        NaN
# 10  Apartments/Condos (3 or more units)       30.0         NaN  2796000.0
# 11  Apartments/Condos (3 or more units)       50.0        80.0  6200000.0
# 12                                  NaN        NaN         NaN        NaN
# 13               Single Family Dwelling        1.0         NaN   290669.0
# 14               Single Family Dwelling        1.0         NaN   179680.0
# 15               Single Family Dwelling        1.0         NaN   183523.0
# 16               Single Family Dwelling        1.0         NaN   311179.0
# 17               Single Family Dwelling        1.0         NaN   308378.0
# 18               Single Family Dwelling        1.0         NaN   230757.0
# 19               Single Family Dwelling        1.0         NaN   218876.0
#
#     Unnamed: 6                                        folder_desc  \
# 0          NaN  CONVERT EXISTING DETACHED GARAGE TO ACCESSORY ...
# 1          NaN  NEW DETACHED TWO STORY ADU IN REAR YARD/GARAGE...
# 2          NaN  NEW DETACHED ADU WITH 128 SQ FT MEZZANINE FOR ...
# 3          NaN  NEW ACCESSORY DWELLING UNIT /  1 STORY / NO GA...
# 4          NaN  NEW ACCESSORY DWELLING UNIT/1-STORY/FLAT LOT/C...
# 5          NaN  CONVERT EXISTING SHARED GARAGE TO ACCESSORY DW...
# 6          NaN  NEW 760 SF ACCESSORY DWELLING UNIT/2 STORY/FLA...
# 7          NaN  NEW DETACHED ADU ABOVE TWO CAR GARAGE/FLAT LOT...
# 8     420221.0  ADDITION TO EXISTING GARAGE TO CREATE NEW ACCE...
# 9          NaN                                                NaN
# 10         NaN  NEW FOUR STORY, 30 UNIT APARTMENT BUILDING WIT...
# 11   8996000.0  NEW APARTMENT BUILDING, 5 STORIES, 50 UNITS; L...
# 12         NaN                                                NaN
# 13         NaN  NEW SINGLE FAMILY RESIDENCE/ 2 STORY/ WITH BAS...
# 14         NaN  NEW SINGLE FAMILY RESIDENCE / 2-STORY / NO GAR...
# 15         NaN  NEW SINGLE FAMILY RESIDENCE/2 STORY/FLAT LOT/C...
# 16         NaN  NEW SINGLE FAMILY RESIDENCE/2-STORY W/BASEMENT...
# 17         NaN  NEW SINGLE FAMILY RESIDENCE/TWO STORY/FINISHED...
# 18         NaN  NEW SINGLE FAMILY RESIDENCE / 2-STORY / DETACH...
# 19         NaN  NEW SINGLE FAMILY RESIDENCE/TWO STORY/ATTACHED...
#
#                                    occ          workdesc  \
# 0   R-3_Residential One and Two Family        Alteration
# 1   R-3_Residential One and Two Family  New Construction
# 2   R-3_Residential One and Two Family  New Construction
# 3   R-3_Residential One and Two Family  New Construction
# 4   R-3_Residential One and Two Family  New Construction
# 5   R-3_Residential One and Two Family        Alteration
# 6   R-3_Residential One and Two Family  New Construction
# 7   R-3_Residential One and Two Family  New Construction
# 8   R-3_Residential One and Two Family          Addition
# 9                                  NaN               NaN
# 10        R-2_Residential Multi-family  New Construction
# 11        R-2_Residential Multi-family  New Construction
# 12                                 NaN               NaN
# 13  R-3_Residential One and Two Family  New Construction
# 14  R-3_Residential One and Two Family  New Construction
# 15  R-3_Residential One and Two Family  New Construction
# 16  R-3_Residential One and Two Family  New Construction
# 17  R-3_Residential One and Two Family  New Construction
# 18  R-3_Residential One and Two Family  New Construction
# 19  R-3_Residential One and Two Family  New Construction
#
#                        ...                      legaldesc proptownship  \
# 0                      ...                            NaN          NaN
# 1                      ...                            NaN          NaN
# 2                      ...                            NaN          NaN
# 3                      ...                            NaN          NaN
# 4                      ...                            NaN          NaN
# 5                      ...                            NaN          NaN
# 6                      ...                            NaN          NaN
# 7                      ...                            NaN          NaN
# 8                      ...                            NaN          NaN
# 9                      ...                            NaN          NaN
# 10                     ...                            NaN       8737.0
# 11                     ...                            NaN       4885.0
# 12                     ...                            NaN          NaN
# 13                     ...                            NaN      20848.0
# 14                     ...                            NaN          NaN
# 15                     ...                            NaN          NaN
# 16                     ...                            NaN          NaN
# 17                     ...                            NaN          NaN
# 18                     ...                            NaN          NaN
# 19                     ...                            NaN          NaN
#
#       propplan  folderrsn     sqft logged                   project_name  \
# 0   R860713900  3469651.0    324.0     OK        4215 NE 20TH AVE Unit B
# 1   R036900810  3475646.0    942.0     OK             6453 SE RAYMOND ST
# 2   R941350600  3426008.0    748.0     OK                204 SE 16TH AVE
# 3   R242302210  3481070.0    444.0     OK        4626 NE 31ST AVE Unit B
# 4   R421302240  3486127.0    323.0     OK               6120 NE 22ND AVE
# 5   R834303130  3504956.0      0.0     OK               3019 SE 21ST AVE
# 6   R413901710  3242638.0    760.0     OK        5324 NE 28TH AVE Unit B
# 7   R173101200  3465918.0    500.0     OK  2116 NE ROSA PARKS WAY Unit B
# 8   R421318050  3497935.0    350.0     OK        5716 NE 32ND AVE Unit B
# 9          NaN        NaN      NaN    NaN                            NaN
# 10  R366703690  3457197.0  21910.0     OK             LANGANO APARTMENTS
# 11  R663100610  3452604.0  39501.0     OK              2640 SE ANKENY ST
# 12         NaN        NaN      NaN    NaN                            NaN
# 13  R358102020  3428116.0   3054.0     OK                914 SE 28TH AVE
# 14  R544500340  3361363.0   1678.0     OK           7111 N GREENWICH AVE
# 15  R421307930  3455909.0   1664.0     OK               6027 NE 27TH AVE
# 16  R655101320  3407480.0   3055.0     OK             7928 N BURRAGE AVE
# 17  R501500010  3480035.0   3042.0     OK            3764 SE STEPHENS ST
# 18  R649900360  3361505.0   2155.0     OK              10810 SW 61ST AVE
# 19  R649802660  3465796.0   2252.0     OK              1720 NE 155TH AVE
#
#                                        applicant_name         architect_names  \
# 0                     CLEARWATER CONSTRUCTION *RYAN *                    NONE
# 1               IVON STREET STUDIO *MICHELLE JERESEK*                    NONE
# 2                  DMS ARCHITECTS, INC *DAVE SPITZER*            DAVE SPITZER
# 3                                     ASHLEY E BARTON                    NONE
# 4   POLYPHON ARCHITECTURE & DESIGN, LLC *SCHUYLER ...                    NONE
# 5                                         COLIN SHARP                    NONE
# 6               MENTRUM ARCHITECTURE *BAYARD MENTRUM*                    NONE
# 7                       URBAN VISIONS *KEVIN PARTAIN*                    NONE
# 8                                       ERIN R CONNOR                    NONE
# 9                                                 NaN                     NaN
# 10  WORKS PARTNERSHIP ARCHITECTURE *CARRIE STRICKL...                    NONE
# 11                      UDG Couch LLC *David Mullens*  MYHRE GROUP ARCHITECTS
# 12                                                NaN                     NaN
# 13                      URBAN VISIONS *KEVIN PARTAIN*                    NONE
# 14                        FASTER PERMITS *MIKE COYLE*                    NONE
# 15                        FASTER PERMITS *MIKE COYLE*                    NONE
# 16                     JONAY PROPERTIES LLC *BEN MAY*                    NONE
# 17     PORTLAND DEVELOPMENT GROUP, LLC *MAJID HABIBI*                    NONE
# 18                        FASTER PERMITS *MIKE COYLE*                    NONE
# 19                                        ALEX BENZAR                    NONE
#
#                                     owner_names
# 0                                  LEANNE WHITE
# 1                     RYAN J KUNZER, WENDY BOSO
# 2               JAMES K FORRISTAL, ADA B KARDOS
# 3                               ASHLEY E BARTON
# 4                 MARC B PETERS, FAUSTINA M ASH
# 5                    COLIN SHARP, KRISTEN SHARP
# 6                               JENNIFER FARMER
# 7             DOSHIE L CLARK, CAROLYN F JOHNSON
# 8                                 ERIN R CONNOR
# 9                                           NaN
# 10               AINALEM SULTESSA, PETROS JARRA
# 11                               UDG ANKENY LLC
# 12                                          NaN
# 13                         EDEN ENTERPRISES LLC
# 14                     EVERETT CUSTOM HOMES INC
# 15                         EVERETT CUSTOM HOMES
# 16                         JONAY PROPERTIES LLC
# 17  PORTLAND DEVELOPMENT GROUP, INVESTMENTS LLC
# 18                                         NONE
# 19                                 LYDIA BENZAR
#
# [20 rows x 27 columns]

# %% [markdown]
# Looks like they're using those columns to total up the valuations for groups of housing types. I'm noticing, too, that there are some blank rows -- probably used as dividers between groups -- so we'll want to drop those as well.
#
# We'll keep that in mind as we roll through these sheets.
#
# Here's the pandas documentation on the methods we'll be using here:
# - [`append()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.append.html)
# - [`drop()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html)
# - [`dropna()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html)

# %%
# loop over the excel file paths
for f in xl_files:
    
    # load the file into a data frame
    # specifying `None` as the sheet name
    df = pd.read_excel(f, sheet_name=None)

    # start off with no match
    match = None
    
    # loop over the worksheet names
    for ws_name in df.keys():
        
        # loop over the word fragments
        for fragment in target_sheet_name_fragments:
            
            # if this fragment exists in the lowercased worksheet name
            if fragment in ws_name.lower():
                
                # we've got a winner
                match = ws_name

    # if, when we get to the end of this, `match` is still None
    if not match:
        # print something to let us know about it
        print(f'NO MATCH FOUND FOR {f}')
        
        # and the names of the sheets
        print(df.keys())
        
        # and break out of the loop
        break
                
    # otherwise, grab a handle to the worksheet we want
    working_df = df[match]
    
    # print a status message to let us know what's up
    print(f'parsing "{match}" worksheet from "{f}"')
    
    # get a list of columns we want to drop
    columns_to_drop = [x for x in working_df.columns if 'Unnamed' in x]
    
    # drop those bad boys
    working_df = working_df.drop(columns_to_drop, axis=1)

    # drop empty rows in place, but only if _all_ of the values are nulls
    working_df.dropna(inplace=True, how='all')
    
    # append to our `housing` data frame
    housing = housing.append(working_df,
                             ignore_index=True,
                             sort=True)
# Out:
# parsing "nrs" worksheet from "../data/portland/02_2017 new res units.xlsx"
# parsing "04_2016 New Res Units" worksheet from "../data/portland/04_2016 New Res Units.xls"
# parsing "2018 01 New Residential Units" worksheet from "../data/portland/2018 01 New Residential Units - checked.xls"
# parsing "03_2016 New Res Units" worksheet from "../data/portland/03_2016 New Res Units.xls"
# parsing "08_2014 New Res Units" worksheet from "../data/portland/08_2014 New Res Units.xls"
# parsing "2017 07 New Residential Units" worksheet from "../data/portland/2017 07 New Residential Units - checked.xls"
# parsing "2017 08 New Residential Units" worksheet from "../data/portland/2017 08 New Residential Units - checked.xls"
# parsing "2018 02 New Residential Units" worksheet from "../data/portland/2018 02 New Residential Units - checked.xls"
# parsing "04_2015 New Res Units" worksheet from "../data/portland/04_2015 New Res Units.xlsx"
# parsing "2017 11 New Residential Units" worksheet from "../data/portland/2017 11 New Residential Units - checked.xls"
# parsing "10_2016 new res units" worksheet from "../data/portland/10_2016 new res units.xlsx"
# parsing "08_2015 New Res Units" worksheet from "../data/portland/08_2015 New Res Units.xlsx"
# parsing "07_2015 New Res Units" worksheet from "../data/portland/07_2015 New Res Units.xlsx"
# parsing "05_2017 new res units" worksheet from "../data/portland/05_2017 new res units.xls"
# parsing "2018 05 New Residential Units" worksheet from "../data/portland/2018 05 New Residential Units - updated.xls"
# parsing "01_2016 New Res Units" worksheet from "../data/portland/01_2016 New Res Units.xls"
# parsing "09_2014 New Res Units" worksheet from "../data/portland/09_2014 New Res Units.xls"
# parsing "12_2014 New Res Units" worksheet from "../data/portland/12_2014 New Res Units.xlsx"
# parsing "02_2016 New Res Units" worksheet from "../data/portland/02_2016 New Res Units.xls"
# parsing "2017 12 New Residential Units" worksheet from "../data/portland/2017 12 New Residential Units - checked.xls"
# parsing "06_2017 new res units" worksheet from "../data/portland/06_2017 new res units.xls"
# parsing "03_2015 New Res Units" worksheet from "../data/portland/03_2015 New Res Units.xlsx"
# parsing "11_2015 New Res Units" worksheet from "../data/portland/11_2015 New Res Units 2.xls"
# parsing "07_2016 new res units" worksheet from "../data/portland/07_2016 new res units.xlsx"
# parsing "08_2016 new res units" worksheet from "../data/portland/08_2016 new res units.xlsx"
# parsing "01_2017 new res units" worksheet from "../data/portland/01_2017 new res units.xlsx"
# parsing "07_2014 New Res Units" worksheet from "../data/portland/07_2014 New Res Units.xls"
# parsing "2018 04 New Residential Units" worksheet from "../data/portland/2018 04 New Residential Units - checked.xls"
# parsing "05_2015 New Res Units" worksheet from "../data/portland/05_2015 New Res Units.xlsx"
# parsing "12_2016 new res units" worksheet from "../data/portland/12_2016 new res units.xlsx"
# parsing "11_2014 New Res Units" worksheet from "../data/portland/11_2014 New Res Units.xls"
# parsing "2018 03 New Residential Units" worksheet from "../data/portland/2018 03 New Residential Units - checked.xls"
# parsing "03_2017 new res units" worksheet from "../data/portland/03_2017 new res units.xlsx"
# parsing "05_2016 New Res Units" worksheet from "../data/portland/05_2016 New Res Units.xlsx"
# parsing "2017 09 New Residential Units" worksheet from "../data/portland/2017 09 New Residential Units - checked.xls"
# parsing "12_2015 New Res Units 2" worksheet from "../data/portland/12_2015 New Res Units.xls"
# parsing "09_2016 new res units" worksheet from "../data/portland/09_2016 new res units.xlsx"
# parsing "06_2016 New Res Units" worksheet from "../data/portland/06_2016 New Res Units.xlsx"
# parsing "2017 10 New Residential Units" worksheet from "../data/portland/2017 10 New Residential Units - checked.xls"
# parsing "2018 06 New Residential Units" worksheet from "../data/portland/2018 06 New Residential Units - checked.xls"
# parsing "10_2014 New Res Units" worksheet from "../data/portland/10_2014 New Res Units.xls"
# parsing "02_2015 New Res Units" worksheet from "../data/portland/02_2015 New Res Units.xlsx"
# parsing "04_2017 new res units" worksheet from "../data/portland/04_2017 new res units.xlsx"
# parsing "06_2015 New Res Units" worksheet from "../data/portland/06_2015 New Res Units.xlsx"
# parsing "10_2015 New Res Units" worksheet from "../data/portland/10_2015 New Res Units.xls"
# parsing "09_2015 LUS stats" worksheet from "../data/portland/09_2015 New Res Units.xlsx"
# parsing "11_2016 new res units" worksheet from "../data/portland/11_2016 new res units.xlsx"

# %%
housing.head()
# Out:
#                              applicant_name architect_names const folder  \
# 0             URBAN VISIONS *KEVIN PARTAIN*            NONE   V-B    NaN
# 1          UDG Umatilla LLC *David Mullens*            NONE   V-A    NaN
# 2             URBAN VISIONS *KEVIN PARTAIN*            NONE   V-B    NaN
# 3  CONCEPT DESIGN & ASSOCIATES *KYM NGUYEN*            NONE   V-B    NaN
# 4                           JEREMY M ECKERT            NONE   V-B    NaN
#
#                                          folder_desc         foldernumber  \
# 0  NEW SINGLE FAMILY RESIDENCE/TWO STORY WITH BAS...  14-134373-000-00-RS
# 1  NEW 4 STORY WOOD FRAME APARTMENT BUILDING WITH...  15-165921-000-00-CO
# 2  NEW SINGLE FAMILY RESIDENCE/TWO STORY WITH BAS...  14-134384-000-00-RS
# 3  NEW SINGLE FAMILY RESIDENCE / 3-STORY (INCLUDE...  14-186131-000-00-RS
# 4  NEW DETACHED ACCESSORY DWELLING UNIT/2-STORY/N...  16-198319-000-00-RS
#
#    folderrsn               indate            issuedate  \
# 0  3439167.0  2014-04-02 00:00:00  2014-08-12 12:49:38
# 1  3628809.0  2015-05-06 00:00:00  2016-01-19 15:40:19
# 2  3439178.0  2014-04-02 00:00:00  2014-09-03 10:56:44
# 3  3491628.0  2014-07-18 00:00:00  2017-02-09 10:58:15
# 4  3848149.0  2016-07-01 00:00:00  2017-02-03 10:22:04
#
#                  legaldesc        ...              propgisid1  proplot  \
# 0  5009-5011 NE 26TH AVE *        ...         1N1E24BB  23300  R186548
# 1  8235-8237 SE 17TH AVE *        ...          1S1E23DC  7300  R267583
# 2  5009-5011 NE 26TH AVE *        ...         1N1E24BB  23300  R186548
# 3                      NaN        ...          1S1E17CA  9600  R146946
# 4                      NaN        ...         1S1E01CA  13500  R269447
#
#      propplan proptownship  rev     sqft            status  \
# 0  R413904750       5393.0  NaN   3054.0  Under Inspection
# 1  R752712850       1338.0  NaN  58576.0  Under Inspection
# 2  R413904750       5393.0  NaN   3054.0  Under Inspection
# 3  R208002770          NaN  NaN   4941.0  Under Inspection
# 4  R763200190          NaN  NaN    800.0            Issued
#
#                                    sub  valuation          workdesc
# 0               Single Family Dwelling   299734.0  New Construction
# 1  Apartments/Condos (3 or more units)  9000000.0  New Construction
# 2               Single Family Dwelling   299734.0  New Construction
# 3               Single Family Dwelling   344731.0  New Construction
# 4              Accessory Dwelling Unit    90120.0  New Construction
#
# [5 rows x 27 columns]

# %%
len(housing)
# Out:
# 5434

# %%
housing.dtypes
# Out:
# applicant_name      object
# architect_names     object
# const               object
# folder              object
# folder_desc         object
# foldernumber        object
# folderrsn          float64
# indate              object
# issuedate           object
# legaldesc           object
# logged              object
# new_units          float64
# occ                 object
# owner_names         object
# project_name        object
# prop_address        object
# propertyroll        object
# propgisid1          object
# proplot             object
# propplan            object
# proptownship       float64
# rev                 object
# sqft               float64
# status              object
# sub                 object
# valuation          float64
# workdesc            object
# dtype: object

# %% [markdown]
# One last thing I'd do, before writing out to file, is parse the date columns as dates:

# %%
# convert "indate" column to datetime
housing.indate = pd.to_datetime(housing.indate)

# convert "indate" column to datetime
housing.issuedate = pd.to_datetime(housing.issuedate)

# %%
housing.head()
# Out:
#                              applicant_name architect_names const folder  \
# 0             URBAN VISIONS *KEVIN PARTAIN*            NONE   V-B    NaN
# 1          UDG Umatilla LLC *David Mullens*            NONE   V-A    NaN
# 2             URBAN VISIONS *KEVIN PARTAIN*            NONE   V-B    NaN
# 3  CONCEPT DESIGN & ASSOCIATES *KYM NGUYEN*            NONE   V-B    NaN
# 4                           JEREMY M ECKERT            NONE   V-B    NaN
#
#                                          folder_desc         foldernumber  \
# 0  NEW SINGLE FAMILY RESIDENCE/TWO STORY WITH BAS...  14-134373-000-00-RS
# 1  NEW 4 STORY WOOD FRAME APARTMENT BUILDING WITH...  15-165921-000-00-CO
# 2  NEW SINGLE FAMILY RESIDENCE/TWO STORY WITH BAS...  14-134384-000-00-RS
# 3  NEW SINGLE FAMILY RESIDENCE / 3-STORY (INCLUDE...  14-186131-000-00-RS
# 4  NEW DETACHED ACCESSORY DWELLING UNIT/2-STORY/N...  16-198319-000-00-RS
#
#    folderrsn     indate           issuedate                legaldesc  \
# 0  3439167.0 2014-04-02 2014-08-12 12:49:38  5009-5011 NE 26TH AVE *
# 1  3628809.0 2015-05-06 2016-01-19 15:40:19  8235-8237 SE 17TH AVE *
# 2  3439178.0 2014-04-02 2014-09-03 10:56:44  5009-5011 NE 26TH AVE *
# 3  3491628.0 2014-07-18 2017-02-09 10:58:15                      NaN
# 4  3848149.0 2016-07-01 2017-02-03 10:22:04                      NaN
#
#          ...              propgisid1  proplot    propplan proptownship  rev  \
# 0        ...         1N1E24BB  23300  R186548  R413904750       5393.0  NaN
# 1        ...          1S1E23DC  7300  R267583  R752712850       1338.0  NaN
# 2        ...         1N1E24BB  23300  R186548  R413904750       5393.0  NaN
# 3        ...          1S1E17CA  9600  R146946  R208002770          NaN  NaN
# 4        ...         1S1E01CA  13500  R269447  R763200190          NaN  NaN
#
#       sqft            status                                  sub  valuation  \
# 0   3054.0  Under Inspection               Single Family Dwelling   299734.0
# 1  58576.0  Under Inspection  Apartments/Condos (3 or more units)  9000000.0
# 2   3054.0  Under Inspection               Single Family Dwelling   299734.0
# 3   4941.0  Under Inspection               Single Family Dwelling   344731.0
# 4    800.0            Issued              Accessory Dwelling Unit    90120.0
#
#            workdesc
# 0  New Construction
# 1  New Construction
# 2  New Construction
# 3  New Construction
# 4  New Construction
#
# [5 rows x 27 columns]

# %% [markdown]
# Now we can use the `to_csv()` method to write out to a new file:

# %%
housing.to_csv('portland-developments.csv', index=False)
