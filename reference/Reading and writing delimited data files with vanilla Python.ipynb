# %% [markdown]
# # Reading and writing delimited data files with vanilla Python
#
# For a data task of any size, it usually makes sense to use a dedicated third-party library like `pandas`. In general, go with the tool that helps you accomplish your task easiest and quickest. It might be an extra step to install third-party dependencies, but you can typically cut down on development time by using a specialized tool like pandas. Sometimes, though, your task is simple enough that you can use built-in Python tools to complete your task, or maybe you don't have a stable Internet connection and you're on deadline, whatever. At any rate, it's good to know that these built-in tools exist.
#
# Python's built-in [`csv`](https://docs.python.org/3.6/index.html) module has functionality for working with delimited data files of all kinds. Let's take it for a spin. We'll work with the MLB data that lives at: `../data/mlb.csv`

# %% [markdown]
# ### Import the module

# %%
import csv

# %% [markdown]
# ### Reading data files
#
# We're going to use a `with` block and the built-in `open()` function to open a data file and read the contents.
#
# With Python's csv module, you can use the `csv.reader()` method to read a data file in as a list of lists, like this:
#
# ```python
# [
#     ['name', 'job', 'age'],
#     ['Cody Winchester', 'Training director', 32],
#     ['Robert Caro', 'Author', 82]
# ]
# ```
#
# ... or as a list of dictionaries (a list of [OrderedDict](https://docs.python.org/3/library/collections.html#collections.OrderedDict) objects, technically), using the `csv.DictReader()` method, like this:
# ```python
# [
#     {'name': 'Cody Winchester', 'job': 'Training director', 'age': 32},
#     {'name': 'Robert Caro', 'job': 'Author', 'age': 82}
# ]
# ```
#
# Which one you use is largely a matter of personal preference. I prefer using `DictReader()` because it allows you to access bits of data by field name instead of list position, which I find more intuitive.

# %%
with open ('../data/mlb.csv', 'r') as f:
    
    # create a reader object
    reader = csv.DictReader(f)
    
    # print the fieldnames
    print(reader.fieldnames)
    
    # loop over the reader object and print the 
    for row in reader:
        print(row['TEAM'], row['NAME'], row['SALARY'])
# Out:
# ['NAME', 'TEAM', 'POS', 'SALARY', 'START_YEAR', 'END_YEAR', 'YEARS']
# LAD Clayton Kershaw 33000000
# ARI Zack Greinke 31876966
# BOS David Price 30000000
# DET Miguel Cabrera 28000000
# DET Justin Verlander 28000000
# CHC Jason Heyward 26055288
# LAA Albert Pujols 26000000
# SEA Felix Hernandez 25857143
# CHC Jon Lester 25000000
# NYY CC Sabathia 25000000
# SEA Robinson Cano 24000000
# TEX Prince Fielder 24000000
# SF Johnny Cueto 23500000
# MIN Joe Mauer 23000000
# BOS Hanley Ramirez 22750000
# TEX Cole Hamels 22500000
# NYM Yoenis Cespedes 22500000
# LAD Adrian Gonzalez 22357142
# SF Buster Posey 22177778
# WSH Max Scherzer 22142857
# DET Justin Upton 22125000
# CIN Joey Votto 22000000
# NYY Masahiro Tanaka 22000000
# NYM Jose Reyes 22000000
# WSH Jayson Werth 21571429
# ATL Matt Kemp 21500000
# BAL Chris Davis 21233006
# NYY Jacoby Ellsbury 21142857
# CWS James Shields 21000000
# ATL Freddie Freeman 20859375
# SF Matt Cain 20833333
# COL Carlos Gonzalez 20428571
# BOS Rick Porcello 20125000
# LAA Mike Trout 20083333
# TOR Troy Tulowitzki 20000000
# TEX Shin-Soo Choo 20000000
# TOR Russell Martin 20000000
# SF Jeff Samardzija 19800000
# STL Adam Wainwright 19500000
# NYM David Wright 19382219
# MIL Ryan Braun 19199365
# CIN Homer Bailey 19000000
# SF Hunter Pence 18700000
# DET Jordan Zimmermann 18000000
# DET Victor Martinez 18000000
# TEX Adrian Beltre 18000000
# TOR Jose Bautista 18000000
# BOS Pablo Sandoval 17600000
# LAD Andre Ethier 17500000
# NYY Aroldis Chapman 17200000
# PHI Jeremy Hellickson 17200000
# NYM Neil Walker 17200000
# HOU Brian McCann 17000000
# TOR Josh Donaldson 17000000
# DET Anibal Sanchez 16800000
# STL Dexter Fowler 16500000
# CHC Ben Zobrist 16500000
# WSH Stephen Strasburg 16428571
# BAL Adam Jones 16352417
# KC Alex Gordon 16000000
# CHC John Lackey 16000000
# HOU Carlos Beltran 16000000
# CHC Jake Arrieta 15637500
# MIA Wei-Yin Chen 15500000
# TEX Elvis Andrus 15333333
# STL Mike Leake 15000000
# NYM Curtis Granderson 15000000
# CWS Melky Cabrera 15000000
# LAD Scott Kazmir 14985384
# CLE Edwin Encarnacion 14666666
# BOS Dustin Pedroia 14642348
# MIA Giancarlo Stanton 14500000
# TOR Marco Estrada 14500000
# SEA Nelson Cruz 14250000
# PIT Andrew McCutchen 14208333
# STL Yadier Molina 14200000
# WSH Ryan Zimmerman 14000000
# CHC Miguel Montero 14000000
# HOU Yulieski Gurriel 14000000
# SEA Hisashi Iwakuma 14000000
# ATL Brandon Phillips 13968236
# TOR Francisco Liriano 13666667
# BAL J.J. Hardy 13636781
# WSH Bryce Harper 13625000
# KC Ian Kennedy 13500000
# MIN Ervin Santana 13500000
# MIN Phil Hughes 13200000
# BAL Ubaldo Jimenez 13173102
# TB Evan Longoria 13119486
# LAD Justin Turner 13000000
# NYY Chase Headley 13000000
# HOU Josh Reddick 13000000
# NYM Jay Bruce 13000000
# BOS Craig Kimbrel 13000000
# TOR J.A. Happ 13000000
# PHI Clay Buchholz 13000000
# NYY Matt Holliday 13000000
# LAD Rich Hill 12666667
# NYY Brett Gardner 12500000
# ATL Bartolo Colon 12500000
# KC Eric Hosmer 12250000
# MIL Matt Garza 12209424
# CWS Jose Abreu 12166667
# LAA Ricky Nolasco 12000000
# CWS David Robertson 12000000
# WSH Gio Gonzalez 12000000
# WSH Daniel Murphy 12000000
# BOS Chris Sale 12000000
# CLE Carlos Santana 12000000
# ATL Jaime Garcia 12000000
# CWS Todd Frazier 12000000
# COL Nolan Arenado 11750000
# DET J.D. Martinez 11750000
# SF Madison Bumgarner 11666667
# LAD Brandon McCarthy 11500000
# MIA Martin Prado 11500000
# BAL Mark Trumbo 11500000
# TEX Carlos Gomez 11500000
# BAL Manny Machado 11500000
# BAL Zach Britton 11400000
# SEA Kyle Seager 11000000
# DET Ian Kinsler 11000000
# TEX Yu Darvish 11000000
# ATL Nick Markakis 11000000
# SF Denard Span 11000000
# KC Lorenzo Cain 11000000
# TOR Kendrys Morales 11000000
# SEA Yovani Gallardo 10888877
# LAD Kenley Jansen 10800000
# WSH Matt Wieters 10500000
# BAL Chris Tillman 10050000
# STL Jhonny Peralta 10000000
# STL Matt Carpenter 10000000
# TEX Andrew Cashner 10000000
# CHC Wade Davis 10000000
# NYY Starlin Castro 9857142
# PHI Howie Kendrick 9540378
# ARI Yasmany Tomas 9500000
# CLE Michael Brantley 9375000
# CLE Jason Kipnis 9166667
# HOU Dallas Keuchel 9150000
# SF Mark Melancon 9000000
# CLE Andrew Miller 9000000
# PIT Francisco Cervelli 9000000
# MIA Edinson Volquez 9000000
# LAA Huston Street 9000000
# LAA Cameron Maybin 9000000
# PHI Michael Saunders 9000000
# BAL Wade Miley 8916667
# ARI Paul Goldschmidt 8833333
# KC Mike Moustakas 8700000
# MIN Jason Castro 8500000
# NYM Asdrubal Cabrera 8250000
# LAD Yasiel Puig 8214285
# SF Brandon Crawford 8200000
# COL Ian Desmond 8000000
# LAA Andrelton Simmons 8000000
# KC Jason Vargas 8000000
# COL Gerardo Parra 8000000
# KC Joakim Soria 8000000
# MIN Hector Santiago 8000000
# CHC Jon Jay 8000000
# LAD Hyun-Jin Ryu 7833333
# STL Brett Cecil 7750000
# PIT Josh Harrison 7750000
# NYM Addison Reed 7750000
# MIA Dee Gordon 7742202
# CLE Corey Kluber 7700000
# PIT Ivan Nova 7666667
# OAK Ryan Madson 7666667
# STL Lance Lynn 7500000
# PHI Joaquin Benoit 7500000
# ATL R.A. Dickey 7500000
# NYM Jeurys Familia 7425000
# NYY Michael Pineda 7400000
# CLE Cody Allen 7350000
# CIN Devin Mesoraco 7325000
# COL Charlie Blackmon 7300000
# CHC Anthony Rizzo 7285714
# NYM Lucas Duda 7250000
# CWS Jose Quintana 7000000
# MIA Brad Ziegler 7000000
# HOU Charlie Morton 7000000
# SF Matt Moore 7000000
# BAL Seth Smith 7000000
# LAA Yunel Escobar 7000000
# LAD Logan Forsythe 7000000
# BAL Darren O'Day 6854712
# SEA Drew Smyly 6850000
# LAA Garrett Richards 6850000
# ARI A.J. Pollock 6750000
# PIT Antonio Bastardo 6625000
# MIA A.J. Ramos 6550000
# OAK Jed Lowrie 6500000
# MIN Glen Perkins 6500000
# CLE Carlos Carrasco 6500000
# LAA Luis Valbuena 6500000
# BOS Chris Young 6500000
# NYM Jerry Blevins 6500000
# PHI Pat Neshek 6500000
# KC Alcides Escobar 6500000
# ATL Julio Teheran 6466666
# STL Trevor Rosenthal 6400000
# HOU Luke Gregerson 6250000
# TOR Steve Pearce 6250000
# PIT David Freese 6250000
# SEA Jean Segura 6200000
# NYY Tyler Clippard 6150000
# STL Jedd Gyorko 6000000
# LAA Kole Calhoun 6000000
# MIN Brian Dozier 6000000
# HOU Tony Sipp 6000000
# DET Francisco Rodriguez 6000000
# SEA Steve Cishek 6000000
# CWS Derek Holland 6000000
# COL Greg Holland 6000000
# CHC Koji Uehara 6000000
# TEX Mike Napoli 6000000
# OAK Rajai Davis 6000000
# TEX Tyson Ross 6000000
# BAL Welington Castillo 6000000
# COL Jake McGee 5900000
# CWS Miguel Gonzalez 5900000
# WSH Anthony Rendon 5800000
# CHC Hector Rondon 5800000
# KC Chris Young 5750000
# ATL Sean Rodriguez 5750000
# LAA Jesse Chavez 5750000
# MIA Tom Koehler 5750000
# PIT Tony Watson 5600000
# SEA Danny Valencia 5550000
# WSH Shawn Kelley 5500000
# STL Zach Duke 5500000
# CHC Pedro Strop 5500000
# PIT Daniel Hudson 5500000
# SEA Marc Rzepczynski 5500000
# OAK Santiago Casilla 5500000
# OAK John Axford 5500000
# CLE Boone Logan 5500000
# BOS Mitch Moreland 5500000
# HOU Norichika Aoki 5500000
# LAD Yasmani Grandal 5500000
# LAA Danny Espinosa 5425000
# MIL Neftali Feliz 5350000
# PIT Starling Marte 5333333
# KC Kelvin Herrera 5325000
# CIN Zack Cozart 5325000
# TEX Jonathan Lucroy 5250000
# OAK Trevor Plouffe 5250000
# HOU Evan Gattis 5200000
# NYM Matt Harvey 5125000
# NYY Didi Gregorius 5100000
# KC Danny Duffy 5000000
# KC Jason Hammel 5000000
# MIA Junichi Tazawa 5000000
# ATL Jim Johnson 5000000
# TB Colby Rasmus 5000000
# OAK Khris Davis 5000000
# OAK Matt Joyce 5000000
# TB Chris Archer 4916667
# SEA Leonys Martin 4850000
# COL DJ LeMahieu 4800000
# ARI Shelby Miller 4700000
# HOU Jose Altuve 4687500
# TEX Martin Perez 4650000
# CLE Bryan Shaw 4600000
# MIA David Phelps 4600000
# CLE Yan Gomes 4583333
# SD Wil Myers 4500000
# SEA Carlos Ruiz 4500000
# NYM Juan Lagares 4500000
# BOS Xander Bogaerts 4500000
# BOS Drew Pomeranz 4450000
# COL Tyler Chatwood 4400000
# MIA Adeiny Hechavarria 4350000
# PHI Freddy Galvis 4350000
# PIT Jordy Mercer 4325000
# WSH Tanner Roark 4315000
# CLE Lonnie Chisenhall 4300000
# MIL Wily Peralta 4275000
# CIN Raisel Iglesias 4214285
# KC Salvador Perez 4200000
# BAL Hyun-soo Kim 4200000
# TB Alex Cobb 4200000
# SF Eduardo Nunez 4200000
# PHI Jeanmar Gomez 4200000
# TOR Justin Smoak 4125000
# TB Jake Odorizzi 4100000
# DET Jose Iglesias 4100000
# NYM Jacob deGrom 4050000
# SF Brandon Belt 4000000
# WSH Adam Eaton 4000000
# COL Mike Dunn 4000000
# TB Wilson Ramos 4000000
# KC Travis Wood 4000000
# PIT John Jaso 4000000
# KC Mike Minor 4000000
# WSH Oliver Perez 4000000
# LAA Ben Revere 4000000
# NYY Chris Carter 4000000
# MIL Eric Thames 4000000
# WSH Joe Blanton 4000000
# OAK Yonder Alonso 4000000
# ARI Patrick Corbin 3950000
# HOU George Springer 3900000
# HOU Collin McHugh 3850000
# KC Brandon Moss 3750000
# STL Jonathan Broxton 3750000
# COL Chad Qualls 3750000
# PIT Gerrit Cole 3750000
# HOU Marwin Gonzalez 3725000
# STL Carlos Martinez 3700000
# KC Jorge Soler 3666666
# PIT Juan Nicasio 3650000
# BOS Jackie Bradley Jr. 3600000
# TB Brad Miller 3575000
# OAK Sonny Gray 3575000
# CLE Trevor Bauer 3550000
# TEX Sam Dyson 3520000
# MIA Christian Yelich 3500000
# CHC Brett Anderson 3500000
# MIA Marcell Ozuna 3500000
# WSH Stephen Drew 3500000
# BAL Jonathan Schoop 3475000
# BAL Kevin Gausman 3450000
# HOU Mike Fiers 3450000
# CLE Danny Salazar 3400000
# TOR Marcus Stroman 3400000
# LAA Matt Shoemaker 3325000
# TB Erasmo Ramirez 3210000
# COL Jordan Lyles 3175000
# TB Kevin Kiermaier 3166667
# LAD Kenta Maeda 3125000
# BAL Brad Brach 3050000
# TB Corey Dickerson 3025000
# MIA Jeff Locke 3025000
# ATL Tyler Flowers 3000000
# PHI Andres Blanco 3000000
# CWS Avisail Garcia 3000000
# NYY Dellin Betances 3000000
# CIN Drew Storen 3000000
# NYM Fernando Salas 3000000
# TOR J.P. Howell 3000000
# TOR Jason Grilli 3000000
# SD Jered Weaver 3000000
# TOR Joe Smith 3000000
# DET Nick Castellanos 3000000
# LAD Sergio Romo 3000000
# OAK Stephen Vogt 2965000
# MIN Brandon Kintzler 2925000
# MIN Kyle Gibson 2900000
# TOR Darwin Barney 2887500
# LAD Alex Wood 2800000
# SEA Jarrod Dyson 2800000
# BOS Joe Kelly 2800000
# STL Matt Adams 2800000
# STL Michael Wacha 2775000
# STL Seung Hwan Oh 2750000
# ATL Ender Inciarte 2700000
# DET Justin Wilson 2700000
# OAK Sean Doolittle 2630000
# SD Yangervis Solarte 2625000
# CIN Billy Hamilton 2625000
# MIN Eduardo Escobar 2600000
# LAD Franklin Gutierrez 2600000
# PHI Cesar Hernandez 2550000
# TEX Jake Diekman 2550000
# CIN Scooter Gennett 2525000
# CLE Josh Tomlin 2500000
# MIA A.J. Ellis 2500000
# STL Aledmys Diaz 2500000
# ARI Fernando Rodney 2500000
# TB Logan Morrison 2500000
# SF Will Smith 2500000
# MIL Chase Anderson 2450000
# SEA James Paxton 2350000
# ARI Chris Owings 2300000
# CIN Scott Feldman 2300000
# NYY Adam Warren 2290000
# PIT Jung-ho Kang 2275000
# STL Kolten Wong 2250000
# LAA Cliff Pennington 2250000
# ARI Jorge De La Rosa 2250000
# ARI Taijuan Walker 2250000
# LAA Yusmeiro Petit 2250000
# HOU Will Harris 2200000
# NYM Wilmer Flores 2200000
# MIL Carlos Torres 2175000
# COL Adam Ottavino 2100000
# TEX Jeremy Jeffress 2100000
# MIN Matt Belisle 2050000
# BOS Tyler Thornburg 2050000
# CLE Brandon Guyer 2000000
# ARI Jeff Mathis 2000000
# TEX A.J. Griffin 2000000
# SF Aaron Hill 2000000
# WSH Adam Lind 2000000
# DET Alex Avila 2000000
# CHC Brian Duensing 2000000
# LAD Chase Utley 2000000
# BOS Fernando Abad 2000000
# CWS Geovany Soto 2000000
# MIA Ichiro Suzuki 2000000
# TB Nate Eovaldi 2000000
# SF Nick Hundley 2000000
# TEX Robinson Chirinos 1950000
# BOS Brock Holt 1950000
# CWS Nate Jones 1900000
# SD Brandon Maurer 1900000
# NYM Travis d'Arnaud 1875000
# CHC Justin Grimm 1825000
# BOS Robbie Ross Jr. 1825000
# CIN Tony Cingrani 1825000
# CLE Zach McAllister 1825000
# BAL Ryan Flaherty 1800000
# SD Christian Friedrich 1790000
# ARI Randall Delgado 1775000
# TEX Tony Barnette 1750000
# LAA Bud Norris 1750000
# SD Clayton Richard 1750000
# MIA Dustin McGowan 1750000
# SD Erick Aybar 1750000
# SF George Kontos 1750000
# SD Jhoulys Chacin 1750000
# NYM Rene Rivera 1750000
# SD Trevor Cahill 1750000
# LAA Martin Maldonado 1725000
# MIA Derek Dietrich 1700000
# BAL Dylan Bundy 1640000
# STL Kevin Siegrist 1637500
# PIT Gregory Polanco 1600000
# PHI Odubel Herrera 1600000
# TB Brad Boxberger 1600000
# WSH Jose Lobaton 1575000
# ATL Arodys Vizcaino 1550000
# KC Drew Butera 1500000
# CLE Austin Jackson 1500000
# ARI Chris Iannetta 1500000
# ATL Kurt Suzuki 1500000
# LAD Luis Avilan 1500000
# COL Mark Reynolds 1500000
# TB Rickie Weeks Jr. 1500000
# PIT Chris Stewart 1400000
# WSH Chris Heisey 1400000
# SF Conor Gillaspie 1400000
# CWS Dan Jennings 1400000
# TB Tommy Hunter 1400000
# SD Brad Hand 1375000
# NYY Aaron Hicks 1350000
# ARI Daniel Descalso 1350000
# PHI Daniel Nava 1350000
# TB Peter Bourjos 1350000
# TEX Rougned Odor 1333333
# SEA Nick Vincent 1325000
# LAD Scott Van Slyke 1325000
# DET Andrew Romine 1300000
# BOS Sandy Leon 1300000
# TB Xavier Cedeno 1300000
# CIN Blake Wood 1275000
# OAK Adam Rosales 1250000
# COL Alexi Amarista 1250000
# LAD Chris Hatcher 1250000
# MIN Craig Breslow 1250000
# ATL Emilio Bonifacio 1250000
# ATL Eric O'Flaherty 1250000
# ATL Jacob Lindgren 1250000
# TOR Jarrod Saltalamacchia 1250000
# MIL Tom Milone 1250000
# ARI Tom Wilhelmsen 1250000
# TB Derek Norris 1200000
# ATL Josh Collmenter 1200000
# DET Alex Wilson 1175000
# MIN Ryan Pressly 1175000
# TOR Ezequiel Carrera 1162500
# TOR Aaron Loup 1125000
# BAL Vidal Nuno 1125000
# CWS Zach Putnam 1117500
# SEA Casey Fien 1100000
# HOU Jake Marisnick 1100000
# OAK Liam Hendriks 1100000
# NYY Tommy Layne 1075000
# CLE Dan Otero 1055000
# SF Cory Gearrin 1050000
# CHC Kris Bryant 1050000
# TEX Jurickson Profar 1005000
# LAA Andrew Bailey 1000000
# KC Peter Moylan 1000000
# TB Shawn Tolleson 1000000
# MIA Tyler Moore 1000000
# SD Carter Capps 987500
# TEX Tanner Scheppers 975000
# CLE Jose Ramirez 971400
# MIN Chris Gimenez 950000
# BOS Mookie Betts 950000
# ARI Chris Herrmann 937500
# SEA Evan Scribner 907500
# CWS Anthony Swarzak 900000
# SD Craig Stammen 900000
# TB Danny Farquhar 900000
# ATL Ian Krol 900000
# ARI J.J. Hoover 900000
# MIL Kirk Nieuwenhuis 900000
# TB Tim Beckham 855000
# CWS Tim Anderson 850000
# DET Bruce Rondon 850000
# BAL Craig Gentry 850000
# CWS Jake Petricka 825000
# NYY Austin Romine 805000
# NYM Zack Wheeler 800000
# SEA Guillermo Heredia 782000
# CHC Kyle Hendricks 760500
# SD Hector Sanchez 750000
# SF Neil Ramirez 750000
# PIT Wade LeBlanc 750000
# ATL Chaz Roe 720000
# BAL Caleb Joseph 700000
# STL Eric Fryer 675000
# NYM Josh Edgin 675000
# CHC Addison Russell 644000
# TB Jesus Sucre 630000
# SF Chris Marrero 610000
# CHC Javier Baez 609000
# NYM Noah Syndergaard 605500
# CWS Carlos Rodon 600000
# ATL Chase d'Arnaud 600000
# MIN Ehire Adrianza 600000
# SF Joe Panik 600000
# BOS Josh Rutledge 600000
# CLE Michael Martinez 600000
# CIN Eugenio Suarez 595000
# BOS Steven Wright 593500
# CIN Anthony DeSclafani 585000
# BOS Eduardo Rodriguez 584500
# BOS Roenis Elias 582500
# CLE Francisco Lindor 579300
# CIN Adam Duvall 577500
# LAD Corey Seager 575500
# OAK Jake Smolinksi 575000
# NYY Pete Kozma 575000
# CIN Tucker Barnhart 575000
# CHC Tommy La Stella 573500
# ARI Jake Lamb 573300
# MIN Miguel Sano 572500
# ARI David Peralta 572200
# KC Nathan Karns 571000
# CHC Mike Montgomery 570500
# ARI Robbie Ray 570400
# SEA Mike Zunino 570000
# CIN Brandon Finnegan 567000
# SD Jarred Cosart 566300
# ARI Nick Ahmed 566000
# CHC Kyle Schwarber 565500
# LAA C.J. Cron 565000
# PHI Cameron Rupp 565000
# CLE Tyler Naquin 564800
# PIT Felipe Rivero 564500
# KC Christian Colon 564000
# WSH Blake Treinen 563700
# BOS Matt Barnes 563500
# MIA J.T. Realmuto 562500
# NYM Steven Matz 562250
# NYY Ronald Torreyes 561900
# BOS Christian Vazquez 561000
# STL Stephen Piscotty 560400
# LAA Blake Parker 560000
# PHI Maikel Franco 560000
# PIT Phil Gosselin 559500
# ARI Andrew Chafin 559300
# KC Paulo Orlando 558250
# NYY Gary Sanchez 557900
# WSH Michael Taylor 557900
# PHI Hector Neris 557500
# LAA Jose Alvarez 557500
# TB Jumbo Diaz 557500
# STL Randal Grichuk 557200
# BOS Carson Smith 556750
# KC Brian Flynn 556000
# CHC Carl Edwards Jr. 556000
# PIT Jameson Taillon 555500
# LAA Cam Bedrosian 555000
# LAD Enrique Hernandez 555000
# SF Hunter Strickland 555000
# ATL Jace Peterson 555000
# LAD Joc Pederson 555000
# TOR Kevin Pillar 555000
# CIN Michael Lorenzen 555000
# MIN Trevor May 555000
# LAA Tyler Skaggs 555000
# LAD Yimi Garcia 555000
# NYM Michael Conforto 554904
# WSH Trea Turner 554900
# HOU Chris Devenski 554500
# MIL Jonathan Villar 554500
# CHC Willson Contreras 554500
# ARI Brandon Drury 553900
# NYM Hansel Robles 553125
# MIN Eddie Rosario 552500
# MIA Justin Bour 552500
# MIN Robbie Grossman 552500
# NYY Chasen Shreve 552425
# TOR Roberto Osuna 552400
# KC Cheslor Cuthbert 552250
# MIA Dan Straily 552100
# DET James McCann 552100
# CHC Albert Almora Jr. 552000
# PHI Jerad Eickhoff 552000
# DET Michael Fulmer 551900
# WSH Enny Romero 551000
# NYY Luis Severino 550975
# NYY Bryan Mitchell 550625
# DET Shane Greene 550600
# HOU Ken Giles 550100
# PIT Chad Kuhl 550000
# LAA JC Ramirez 550000
# LAD Pedro Baez 550000
# CLE Roberto Perez 550000
# STL Tyler Lyons 549800
# PIT Adam Frazier 549500
# CHC Matt Szczur 549500
# BOS Andrew Benintendi 549000
# PIT Josh Bell 549000
# ARI Jake Barrett 548300
# TOR Dominic Leone 548200
# TOR Ryan Goins 548200
# HOU Lance McCullers Jr. 548000
# TB Alex Colome 547900
# STL Greg Garcia 547900
# ATL Adonis Garcia 547500
# LAA Carlos Perez 547500
# TB Matt Andriese 547500
# MIN Max Kepler 547500
# BOS Heath Hembree 547000
# LAA Jefry Marte 547000
# MIL Jimmy Nelson 547000
# CWS Tyler Saladino 547000
# PHI Vince Velasquez 547000
# TB Steven Souza Jr. 546700
# STL Matt Bowman 546600
# CWS Leury Garcia 546500
# TEX Nomar Mazara 546450
# DET Kyle Ryan 546400
# MIL Junior Guerra 546200
# HOU Michael Feliz 546200
# SD Ryan Schimpf 546200
# MIL Zach Davies 546200
# BAL Mychal Givens 546000
# CWS Yolmer Sanchez 546000
# SD Colin Rea 545800
# MIL Hernan Perez 545700
# WSH Sammy Solis 545700
# DET Daniel Norris 545500
# SD Robbie Erlin 545500
# TB Matt Duffy 545300
# TOR Devon Travis 545200
# TEX Alex Claudio 545050
# TB Blake Snell 545000
# COL Chad Bettis 545000
# COL Chris Rusin 545000
# MIN Danny Santana 545000
# ATL Danny Winkler 545000
# SF Derek Law 545000
# SEA Edwin Diaz 545000
# NYY Greg Bird 545000
# OAK Josh Phegley 545000
# LAD Josh Ravin 545000
# OAK Kendall Graveman 545000
# OAK Marcus Semien 545000
# OAK Mark Canha 545000
# BAL Tyler Wilson 545000
# TEX Matt Bush 544920
# TEX Ryan Rua 544740
# SD Ryan Buchter 544700
# DET Tyler Collins 544700
# NYY Aaron Judge 544500
# MIL Travis Shaw 544400
# SD Luis Perdomo 544300
# SD Travis Jankowski 544300
# CLE Abraham Almonte 544200
# DET Matt Boyd 544200
# ARI Archie Bradley 544100
# PHI Aaron Nola 544000
# ATL Mike Foltynewicz 544000
# SEA Shawn O'Malley 544000
# PIT Trevor Williams 544000
# NYY Tyler Austin 544000
# NYM Seth Lugo 543500
# HOU Joe Musgrove 543400
# LAA Andrew Heaney 543000
# TOR Bo Schultz 543000
# TOR Joe Biagini 543000
# PHI Tommy Joseph 543000
# TOR Ryan Tepera 542700
# ARI Jeremy Hazelbaker 542500
# MIN Michael Tonkin 542500
# LAA Nick Tropeano 542500
# MIN Taylor Rogers 542500
# MIN Tyler Duffey 542500
# MIL Domingo Santana 542200
# SF Trevor Brown 542000
# SD Christian Bethancourt 541800
# SD Luis Sardinas 541800
# NYM Robert Gsellman 541750
# PIT Alen Hanson 541500
# SD Alex Dickerson 541500
# HOU Brad Peacock 541500
# NYM Rafael Montero 541400
# DET Mikie Mahtook 541300
# MIL Keon Broxton 541200
# PIT Tyler Glasnow 541000
# SEA Ariel Miranda 540500
# TEX Delino DeShields 540300
# MIL Jhan Marinez 540200
# LAD Andrew Toles 540000
# LAD Austin Barnes 540000
# OAK Chris Bassitt 540000
# COL Cristhian Adames 540000
# ATL Dansby Swanson 540000
# PHI Edubray Ramos 540000
# LAD Grant Dayton 540000
# COL Jairo Diaz 540000
# COL Jon Gray 540000
# MIN Jorge Polanco 540000
# CIN Jose Peraza 540000
# CWS Michael Ynoa 540000
# CWS Omar Narvaez 540000
# LAD Ross Stripling 540000
# OAK Ryan Dull 540000
# MIN Ryan O'Rourke 540000
# COL Scott Oberg 540000
# CIN Scott Schebler 540000
# COL Tony Wolters 540000
# COL Trevor Story 540000
# COL Tyler Anderson 540000
# NYM T.J. Rivera 539958
# MIL Jett Bandy 539800
# TB Mallex Smith 539800
# SEA Tony Zych 539600
# ARI Socrates Brito 539500
# HOU Alex Bregman 539400
# CLE Cody Anderson 539100
# PHI Adam Morgan 539000
# TOR Dalton Pompey 539000
# SF Jarrett Parker 539000
# BAL Joey Rickard 539000
# SF Mac Williamson 539000
# MIL Corey Knebel 538900
# KC Matt Strahm 538900
# TEX Dario Alvarez 538790
# PHI Aaron Altherr 538500
# BAL Donnie Hart 538500
# WSH Koda Glover 538300
# MIL Manny Pina 538200
# ARI Steve Hathaway 538200
# MIL Orlando Arcia 538100
# CIN Arismendy Alcantara 538000
# SEA Mitch Haniger 538000
# BAL Oliver Drake 538000
# DET Dixon Machado 537800
# WSH Wilmer Difo 537800
# MIL Jacob Barnes 537700
# MIL Taylor Jungmann 537600
# MIA Adam Conley 537500
# OAK Andrew Triggs 537500
# LAD Brock Stewart 537500
# OAK Daniel Coulombe 537500
# OAK Daniel Mengden 537500
# OAK Frankie Montas 537500
# ATL Mauricio Cabrera 537500
# STL Miguel Socolovich 537500
# SEA Rob Whalen 537500
# OAK Ryon Healy 537500
# OAK Sean Manaea 537500
# MIL Andrew Susac 537400
# TEX Hanser Alberto 537360
# KC Raul Mondesi 537250
# NYM Ty Kelly 537208
# HOU Jandel Gustave 537200
# SEA Taylor Motter 537200
# TEX Joey Gallo 537120
# SD Austin Hedges 537100
# TEX Brett Nicholas 537000
# COL Carlos Estevez 537000
# TEX Chi Chi Gonzalez 537000
# CIN Cody Reed 537000
# COL David Dahl 537000
# COL Dustin Garneau 537000
# COL German Marquez 537000
# SF Gorkys Hernandez 537000
# CIN Nefi Ogando 537000
# BOS Robby Scott 537000
# COL Tom Murphy 537000
# PHI Zach Eflin 537000
# NYY Jonathan Holder 536875
# NYM Josh Smoker 536625
# SEA Dillon Overton 536600
# STL John Gant 536600
# SEA James Pazos 536500
# MIA Kyle Barraclough 536500
# CWS Matt Davidson 536500
# STL Sam Tuivailala 536500
# KC Terrance Gore 536500
# SF Ty Blach 536500
# ATL Jose A. Ramirez 536250
# NYM Brandon Nimmo 536240
# SEA Shae Simmons 536200
# SEA Dan Altavilla 536100
# HOU David Paulino 536100
# KC Hunter Dozier 536100
# DET JaCoby Jones 536100
# CWS Charlie Tilson 536000
# MIL Jesus Aguilar 536000
# TEX Jose Leclerc 536000
# BAL Trey Mancini 536000
# SD Hunter Renfroe 535900
# SD Buddy Baumann 535700
# CLE Shawn Armstrong 535700
# SD Manuel Margot 535600
# SD Jose Torres 535400
# TOR Aaron Sanchez 535000
# MIN Adalberto Mejia 535000
# STL Alex Reyes 535000
# SD Allen Cordoba 535000
# CIN Amir Garrett 535000
# PHI Andrew Knapp 535000
# BAL Anthony Santander 535000
# COL Antonio Senzatela 535000
# ATL Armando Rivero 535000
# CIN Austin Brice 535000
# TB Austin Pruitt 535000
# CIN Barrett Astin 535000
# BOS Ben Taylor 535000
# PHI Brock Stassi 535000
# MIN Byron Buxton 535000
# HOU Carlos Correa 535000
# CWS Cody Asche 535000
# TB Daniel R. Robertson 535000
# TEX Drew Robinson 535000
# CWS Dylan Covey 535000
# TOR Glenn Sparkman 535000
# CWS Jacob May 535000
# OAK Jharel Cotton 535000
# PHI Joely Rodriguez 535000
# OAK Joey Wendle 535000
# WSH Jose Marmolejos 535000
# STL Jose Martinez 535000
# MIA Jose Urena 535000
# CWS Juan Minaya 535000
# MIN Justin Haley 535000
# TB Kevin Gadea 535000
# COL Kyle Freeland 535000
# SD Luis Torrens 535000
# ATL Micah Johnson 535000
# SD Miguel Diaz 535000
# MIA Miguel Rojas 535000
# TEX Mike Hauschild 535000
# CIN Nick Travieso 535000
# MIA Nick Wittgren 535000
# MIA Odrisamer Despaigne 535000
# CIN Patrick Kivlehan 535000
# OAK Raul Alcantara 535000
# CIN Robert Stephenson 535000
# CIN Rookie Davis 535000
# COL Stephen Cardullo 535000
# BOS Steve Selsky 535000
# CIN Stuart Turner 535000
# LAA Vicente Campos 535000
# CIN Wandy Peralta 535000
# CLE Yandy Diaz 535000

# %% [markdown]
# ### Writing data files
#
# We'll use a `with` block again to open a file in write (`w`) mode.
#
# As with reading, so with writing: You can write files using the `csv.writer()` method, which takes lists of data, or the `csv.DictWriter()` method, which accepts dictionaries. Again, I prefer the dictionary-based approach.
#
# If you use `csv.writer()`, you'll need to write a list of headers in addition to your data. With `csv.DictWriter()`, you specify the headers by passing a list of headers to the `fieldnames` keyword argument as you create the writer object. Then you can use the object's `writeheader()` method to write out the header row. Important: The keys in your dictionary must match _exactly_ the list of headers you pass to the writer object.
#
# Both writer objects have a `writerow()` method, for writing out a single row of data, and a `writerows()` method (plural) for writing a collection of data.

# %%
new_mlb_players = [
    {'NAME': 'Jeff Tweedy', 'POS': 'SP', 'SALARY': 1000000, 'START_YEAR': 2015, 'END_YEAR': 2019, 'YEARS': 5},
    {'NAME': 'John Stirratt', 'POS': '1B', 'SALARY': 950000, 'START_YEAR': 2015, 'END_YEAR': 2019, 'YEARS': 5},
    {'NAME': 'Nels Cline', 'POS': 'C', 'SALARY': 900000, 'START_YEAR': 2015, 'END_YEAR': 2019, 'YEARS': 5},
    {'NAME': 'Pat Sansone', 'POS': 'SS', 'SALARY': 850000, 'START_YEAR': 2015, 'END_YEAR': 2019, 'YEARS': 5},
    {'NAME': 'Mikael Jorgensen', 'POS': 'RP', 'SALARY': 800000, 'START_YEAR': 2015, 'END_YEAR': 2019, 'YEARS': 5},
    {'NAME': 'Glenn Kotche', 'POS': '3B', 'SALARY': 750000, 'START_YEAR': 2015, 'END_YEAR': 2019, 'YEARS': 5},
]

with open('new-mlb-players.csv', 'w', newline='') as f:
    headers = ['NAME', 'POS', 'SALARY', 'START_YEAR', 'END_YEAR', 'YEARS']
    writer = csv.DictWriter(f, fieldnames=headers)
    
    writer.writeheader()
    writer.writerows(new_mlb_players)

# %% [markdown]
# ### Reading _and_ writing data files
#
# You can open multple files for reading and writing in the same `with` block. A simple use case might be filtering a CSV to get a subset of data, which is what we'll do here.

# %%
with open('../data/mlb.csv', 'r') as infile, open('royals.csv', 'w') as outfile:
    reader = csv.DictReader(infile)
    headers = reader.fieldnames
    writer = csv.DictWriter(outfile, fieldnames=headers)
    
    writer.writeheader()
    
    for row in reader:
        if row['TEAM'] == 'KC':
            writer.writerow(row)

# %% [markdown]
# The equivalent code in `pandas` is much more terse:
#
# ```python
# import pandas as pd
#
# df = pd.read_csv('../data/mlb.csv')
# royals = df[df['TEAM'] == 'KC']
# royals.to_csv('royals.csv')
# ```
